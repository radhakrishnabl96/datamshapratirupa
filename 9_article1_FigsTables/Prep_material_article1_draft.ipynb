# %% [markdown]
# Description: This is a jupyter notebook that provides the code for extracting datasets and plotting the figures and tables necessary for publishing. It is a draft version which will later on be refined based on the guidelines of the publishing house.

# %% [markdown]
# The article will also have two figures: Conceptual process models and three cases (varying top boundary conditions).
#
# Considering the following color pallet for color blindness - https://gist.github.com/thriveth/8560036
# - '#377eb8' - Blue - Case 1
# - '#e41a1c'- red - Case 2
# - '#4daf4a' - green - Case 3

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.gridspec as gridspec
import h5py
import os
import cmcrameri
import dataframe_image as dfi

# %% [markdown]
# ### 1. Input data

# %% [markdown]
# #### 1.1 Forcing input data - Spinup
# - Read more about in File: datamshapratirupa\1_data_prep\AWS_final_metdata_4yrs_concise_spinup.ipynb

# %%
os.getcwd()
# Out:
# 'D:\\Github\\datamshapratirupa\\9_article1_FigsTables'

# %%
# Spinup data

data_AWS_input_spinup_10yrs_actual = pd.read_csv('..\\1_data_prep\\Input_data_Spinup\\Spinup_input_2017_10yrs.csv',sep=',')

# %%
fig2 = plt.figure(figsize=(14,10), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

f2_ax1.set_title('Wind speed at 10 m [m s^-1]', fontsize=13)
f2_ax1.plot(data_AWS_input_spinup_10yrs_actual['Wind speed at 10 m (m/s)'],'k', label='Wind speed at 10 m (m/s)')
f2_ax1.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax1.grid(True)

f2_ax2.set_title('Temperature [K]', fontsize=13)
f2_ax2.plot(data_AWS_input_spinup_10yrs_actual['air temperature [K]'], 'r',label='Air temperature')
f2_ax2.plot(data_AWS_input_spinup_10yrs_actual['Soil temperature at - 0.00 m [K]'], 'k',label='Soil temperature at 0.00 m')
f2_ax2.set_ylabel('[K]')
#f2_ax1.set_xlabel('Date')
f2_ax2.legend()
#f2_ax2.grid(True)

f2_ax3.set_title('Liquid precipitation [m s^-1]', fontsize=13)
f2_ax3.bar(x=np.arange(0,3650,1), height=data_AWS_input_spinup_10yrs_actual['precipitation rain [m s^-1]'],label='precipitation rain [m s^-1]')
f2_ax3.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax3.grid(True)

f2_ax4.set_title('Relative humidity at 5 m [%]', fontsize=13)
f2_ax4.plot(data_AWS_input_spinup_10yrs_actual['Relative humidity at 5 m (%)'], 'g',label='Relative humidity at 5 m')
f2_ax4.set_ylabel('[%]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax4.grid(True)

f2_ax5.set_title('Incoming shortwave radiation [W m^-2]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
f2_ax5.plot(data_AWS_input_spinup_10yrs_actual['Incoming shortwave radiation (W/m^2)'], 'y',label='sw')
f2_ax5.set_ylabel('[W m^-2]')
#f2_ax1.set_xlabel('Date')
#f2_ax5.legend()
#f2_ax5.grid(True)

f2_ax6.set_title('Solid precipitation [m SWE s^-1]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.01'], 'c',label='sd=0.01')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.04'], 'c',label='sd=0.04')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.1'], 'c',label='sd=0.1')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.2'], 'm',label='sd=0.2')
f2_ax6.bar(np.arange(0,3650,1), data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.45'],label='snow density=0.45 kg m^-3')
f2_ax6.set_ylabel('[m SWE s^-1]')
f2_ax6.set_xlabel('[Number of days]',fontsize=14)
f2_ax6.legend()
#f2_ax6.grid(True)

plt.savefig("Spinup_InputData.jpg", dpi=300)

# %% [markdown]
# Comments:
#
# * Since the data is repeated yearly, we can plot the dataset for 1 year instead and show it as a plot
# * We checked if the following figure is suitable for color blind people through the link - https://www.color-blindness.com/coblis-color-blindness-simulator/. It was not suitable mainly for people suffering from Monochromacy. Especially when we have two plots, such as in the second figure. Therefore, we are using a dashed line.

# %%
fig2 = plt.figure(figsize=(14,10), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

f2_ax1.set_title('Wind speed at 10 m [m s^-1]', fontsize=13)
f2_ax1.plot(data_AWS_input_spinup_10yrs_actual['Wind speed at 10 m (m/s)'],'k', label='Wind speed at 10 m (m/s)')
f2_ax1.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax1.grid(True)

f2_ax2.set_title('Temperature [K]', fontsize=13)
f2_ax2.plot(data_AWS_input_spinup_10yrs_actual['air temperature [K]'], 'r-.',label='Air temperature')
f2_ax2.plot(data_AWS_input_spinup_10yrs_actual['Soil temperature at - 0.00 m [K]'], 'k',label='Soil temperature at 0.00 m')
f2_ax2.set_ylabel('[K]')
#f2_ax1.set_xlabel('Date')
f2_ax2.legend()
#f2_ax2.grid(True)

f2_ax3.set_title('Liquid precipitation [m s^-1]', fontsize=13)
f2_ax3.bar(x=np.arange(0,3650,1), height=data_AWS_input_spinup_10yrs_actual['precipitation rain [m s^-1]'],label='precipitation rain [m s^-1]')
f2_ax3.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax3.grid(True)

f2_ax4.set_title('Relative humidity at 5 m [%]', fontsize=13)
f2_ax4.plot(data_AWS_input_spinup_10yrs_actual['Relative humidity at 5 m (%)'], 'g',label='Relative humidity at 5 m')
f2_ax4.set_ylabel('[%]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax4.grid(True)

f2_ax5.set_title('Incoming shortwave radiation [W m^-2]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
f2_ax5.plot(data_AWS_input_spinup_10yrs_actual['Incoming shortwave radiation (W/m^2)'], 'y',label='sw')
f2_ax5.set_ylabel('[W m^-2]')
#f2_ax1.set_xlabel('Date')
#f2_ax5.legend()
#f2_ax5.grid(True)

f2_ax6.set_title('Solid precipitation [m SWE s^-1]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.01'], 'c',label='sd=0.01')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.04'], 'c',label='sd=0.04')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.1'], 'c',label='sd=0.1')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.2'], 'm',label='sd=0.2')
f2_ax6.bar(np.arange(0,3650,1), data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.45'],label='snow density=0.45 kg m^-3')
f2_ax6.set_ylabel('[m SWE s^-1]')
f2_ax6.set_xlabel('[Number of days]',fontsize=14)
f2_ax6.legend()
#f2_ax6.grid(True)

plt.savefig("Spinup_InputData_c.jpg", dpi=300)

# %%
data_AWS_input_spinup_10yrs_actual['Wind speed at 10 m (m/s)'][:365]
# Out:
# 0      5.703646
# 1      4.522028
# 2      5.572090
# 3      6.037000
# 4      5.978368
#          ...
# 360    4.939896
# 361    3.817076
# 362    5.268875
# 363    7.261236
# 364    5.897826
# Name: Wind speed at 10 m (m/s), Length: 365, dtype: float64

# %%
fig2 = plt.figure(figsize=(14,10), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

f2_ax1.set_title('Wind speed at 10 m [m s^-1]', fontsize=13)
f2_ax1.plot(data_AWS_input_spinup_10yrs_actual['Wind speed at 10 m (m/s)'][:365],'k', label='Wind speed at 10 m (m/s)')
f2_ax1.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax1.grid(True)

f2_ax2.set_title('Temperature [K]', fontsize=13)
f2_ax2.plot(data_AWS_input_spinup_10yrs_actual['air temperature [K]'][:365], 'r',label='Air temperature')
f2_ax2.plot(data_AWS_input_spinup_10yrs_actual['Soil temperature at - 0.00 m [K]'][:365], 'k',label='Soil temperature at 0.00 m')
f2_ax2.set_ylabel('[K]')
#f2_ax1.set_xlabel('Date')
f2_ax2.legend()
#f2_ax2.grid(True)

f2_ax3.set_title('Liquid precipitation [m s^-1]', fontsize=13)
f2_ax3.bar(np.arange(0,365,1), data_AWS_input_spinup_10yrs_actual['precipitation rain [m s^-1]'][:365],label='precipitation rain [m s^-1]')
f2_ax3.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax3.grid(True)

f2_ax4.set_title('Relative humidity at 5 m [%]', fontsize=13)
f2_ax4.plot(data_AWS_input_spinup_10yrs_actual['Relative humidity at 5 m (%)'][:365], 'g',label='Relative humidity at 5 m')
f2_ax4.set_ylabel('[%]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax4.grid(True)

f2_ax5.set_title('Incoming shortwave radiation [W m^-2]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
f2_ax5.plot(data_AWS_input_spinup_10yrs_actual['Incoming shortwave radiation (W/m^2)'][:365], 'y',label='sw')
f2_ax5.set_ylabel('[W m^-2]')
#f2_ax1.set_xlabel('Date')
#f2_ax5.legend()
#f2_ax5.grid(True)

f2_ax6.set_title('Solid precipitation [m SWE s^-1]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.01'], 'c',label='sd=0.01')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.04'], 'c',label='sd=0.04')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.1'], 'c',label='sd=0.1')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.2'], 'm',label='sd=0.2')
f2_ax6.bar(np.arange(0,365,1), data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.45'][:365],label='snow density=0.45 kg m^-3')
f2_ax6.set_ylabel('[m SWE s^-1]')
f2_ax6.set_xlabel('[Number of days]',fontsize=14)
f2_ax6.legend()
#f2_ax6.grid(True)

plt.savefig("Spinup_InputData_1yr.jpg", dpi=300)

# %%
fig2 = plt.figure(figsize=(14,10), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

f2_ax1.set_title('Wind speed at 10 m [m s^-1]', fontsize=13)
f2_ax1.plot(data_AWS_input_spinup_10yrs_actual['Wind speed at 10 m (m/s)'][:365],'k', label='Wind speed at 10 m (m/s)')
f2_ax1.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax1.grid(True)

f2_ax2.set_title('Temperature [K]', fontsize=13)
f2_ax2.plot(data_AWS_input_spinup_10yrs_actual['air temperature [K]'][:365], 'r-.',label='Air temperature')
f2_ax2.plot(data_AWS_input_spinup_10yrs_actual['Soil temperature at - 0.00 m [K]'][:365], 'k',label='Soil temperature at 0.00 m')
f2_ax2.set_ylabel('[K]')
#f2_ax1.set_xlabel('Date')
f2_ax2.legend()
#f2_ax2.grid(True)

f2_ax3.set_title('Liquid precipitation [m s^-1]', fontsize=13)
f2_ax3.bar(np.arange(0,365,1), data_AWS_input_spinup_10yrs_actual['precipitation rain [m s^-1]'][:365],label='precipitation rain [m s^-1]')
f2_ax3.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax3.grid(True)

f2_ax4.set_title('Relative humidity at 5 m [%]', fontsize=13)
f2_ax4.plot(data_AWS_input_spinup_10yrs_actual['Relative humidity at 5 m (%)'][:365], 'g',label='Relative humidity at 5 m')
f2_ax4.set_ylabel('[%]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax4.grid(True)

f2_ax5.set_title('Incoming shortwave radiation [W m^-2]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
f2_ax5.plot(data_AWS_input_spinup_10yrs_actual['Incoming shortwave radiation (W/m^2)'][:365], 'y',label='sw')
f2_ax5.set_ylabel('[W m^-2]')
#f2_ax1.set_xlabel('Date')
#f2_ax5.legend()
#f2_ax5.grid(True)

f2_ax6.set_title('Solid precipitation [m SWE s^-1]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.01'], 'c',label='sd=0.01')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.04'], 'c',label='sd=0.04')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.1'], 'c',label='sd=0.1')
#f2_ax6.plot(data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.2'], 'm',label='sd=0.2')
f2_ax6.bar(np.arange(0,365,1), data_AWS_input_spinup_10yrs_actual['precipitation snow [m SWE s^-1]_sd0.45'][:365],label='snow density=0.45 kg m^-3')
f2_ax6.set_ylabel('[m SWE s^-1]')
f2_ax6.set_xlabel('[Number of days]',fontsize=14)
f2_ax6.legend()
#f2_ax6.grid(True)

plt.savefig("Spinup_InputData_1yr_c.jpg", dpi=300)

# %% [markdown]
# #### 1.2 Forcing input data - Calibration + Validation

# %% [markdown]
# - Read more about in File: datamshapratirupa\1_data_prep\AWS_final_metdata_4yrs_concise.ipynb

# %%
os.getcwd()
# Out:
# 'D:\\Github\\datamshapratirupa\\9_article1_FigsTables'

# %%
# Spinup data

data_AWS_input_CalibValid = pd.read_csv('..\\1_data_prep\\Final_InputData_4yrs\\CalibValid_data_2016_2019.csv',sep=',',index_col="TIMESTAMP")

# %%
data_AWS_input_CalibValid.head()
# Out:
#             air temperature [K]  Soil temperature at - 0.00 m [K]  \
# TIMESTAMP
# 2016-01-01           261.261563                        260.046042
# 2016-01-02           262.118340                        260.894583
# 2016-01-03           259.703889                        260.412500
# 2016-01-04           258.583056                        260.143403
# 2016-01-05           259.050764                        259.624722
#
#             Wind speed at 10 m (m/s)  precipitation rain [m s^-1]  \
# TIMESTAMP
# 2016-01-01                  6.880639                          0.0
# 2016-01-02                  5.634090                          0.0
# 2016-01-03                  4.129521                          0.0
# 2016-01-04                  6.604604                          0.0
# 2016-01-05                  4.566090                          0.0
#
#             Relative humidity at 5 m (%)  \
# TIMESTAMP
# 2016-01-01                      0.181419
# 2016-01-02                      0.243579
# ...

# %%
data_AWS_input_CalibValid.index = pd.to_datetime(data_AWS_input_CalibValid.index)

# %%
len(data_AWS_input_CalibValid)
# Out:
# 1461

# %%
fig2 = plt.figure(figsize=(14,10), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

f2_ax1.set_title('Wind speed at 10 m [m s^-1]', fontsize=13)
f2_ax1.plot(data_AWS_input_CalibValid['Wind speed at 10 m (m/s)'],'k', label='Wind speed at 10 m (m/s)')
f2_ax1.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax1.grid(True)

f2_ax2.set_title('Temperature [K]', fontsize=13)
f2_ax2.plot(data_AWS_input_CalibValid['air temperature [K]'], 'r',label='Air temperature')
f2_ax2.plot(data_AWS_input_CalibValid['Soil temperature at - 0.00 m [K]'], 'k',label='Soil temperature at 0.00 m')
f2_ax2.set_ylabel('[K]')
#f2_ax1.set_xlabel('Date')
f2_ax2.legend()
#f2_ax2.grid(True)

f2_ax3.set_title('Liquid precipitation [m s^-1]', fontsize=13)
f2_ax3.bar(data_AWS_input_CalibValid.index,data_AWS_input_CalibValid['precipitation rain [m s^-1]'],label='precipitation rain [m s^-1]')
f2_ax3.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax3.grid(True)

f2_ax4.set_title('Relative humidity at 5 m [%]', fontsize=13)
f2_ax4.plot(data_AWS_input_CalibValid['Relative humidity at 5 m (%)'], 'g',label='Relative humidity at 5 m')
f2_ax4.set_ylabel('[%]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax4.grid(True)

f2_ax5.set_title('Incoming shortwave radiation [W m^-2]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
f2_ax5.plot(data_AWS_input_CalibValid['Incoming shortwave radiation (W/m^2)'], 'y',label='sw')
f2_ax5.set_ylabel('[W m^-2]')
#f2_ax1.set_xlabel('Date')
#f2_ax5.legend()
#f2_ax5.grid(True)

f2_ax6.set_title('Solid precipitation [m SWE s^-1]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
#f2_ax6.plot(data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.01'], 'c',label='sd=0.01')
#f2_ax6.plot(data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.04'], 'c',label='sd=0.04')
#f2_ax6.plot(data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.1'], 'c',label='sd=0.1')
#f2_ax6.plot(data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.2'], 'm',label='sd=0.2')
f2_ax6.bar(data_AWS_input_CalibValid.index, data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.45'],label='snow density=0.45 kg m^-3')
f2_ax6.set_ylabel('[m SWE s^-1]')
f2_ax6.set_xlabel('[Number of days]',fontsize=14)
f2_ax6.legend()
#f2_ax6.grid(True)

plt.savefig("CalibValid_InputData.jpg", dpi=300)

# %%
fig2 = plt.figure(figsize=(14,10), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

f2_ax1.set_title('Wind speed at 10 m [m s^-1]', fontsize=13)
f2_ax1.plot(data_AWS_input_CalibValid['Wind speed at 10 m (m/s)'],'k', label='Wind speed at 10 m (m/s)')
f2_ax1.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax1.grid(True)

f2_ax2.set_title('Temperature [K]', fontsize=13)
f2_ax2.plot(data_AWS_input_CalibValid['air temperature [K]'], 'r-.',label='Air temperature')
f2_ax2.plot(data_AWS_input_CalibValid['Soil temperature at - 0.00 m [K]'], 'k',label='Soil temperature at 0.00 m')
f2_ax2.set_ylabel('[K]')
#f2_ax1.set_xlabel('Date')
f2_ax2.legend()
#f2_ax2.grid(True)

f2_ax3.set_title('Liquid precipitation [m s^-1]', fontsize=13)
f2_ax3.bar(data_AWS_input_CalibValid.index,data_AWS_input_CalibValid['precipitation rain [m s^-1]'],label='precipitation rain [m s^-1]')
f2_ax3.set_ylabel('[m s^-1]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax3.grid(True)

f2_ax4.set_title('Relative humidity at 5 m [%]', fontsize=13)
f2_ax4.plot(data_AWS_input_CalibValid['Relative humidity at 5 m (%)'], 'g',label='Relative humidity at 5 m')
f2_ax4.set_ylabel('[%]')
#f2_ax1.set_xlabel('Date')
#f2_ax1.legend()
#f2_ax4.grid(True)

f2_ax5.set_title('Incoming shortwave radiation [W m^-2]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
f2_ax5.plot(data_AWS_input_CalibValid['Incoming shortwave radiation (W/m^2)'], 'y',label='sw')
f2_ax5.set_ylabel('[W m^-2]')
#f2_ax1.set_xlabel('Date')
#f2_ax5.legend()
#f2_ax5.grid(True)

f2_ax6.set_title('Solid precipitation [m SWE s^-1]', fontsize=13)
#f2_ax5.plot(data_AWS_input_final['Incoming longwave radiation (W/m^2)'], 'k',label='lw')
#f2_ax6.plot(data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.01'], 'c',label='sd=0.01')
#f2_ax6.plot(data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.04'], 'c',label='sd=0.04')
#f2_ax6.plot(data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.1'], 'c',label='sd=0.1')
#f2_ax6.plot(data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.2'], 'm',label='sd=0.2')
f2_ax6.bar(data_AWS_input_CalibValid.index, data_AWS_input_CalibValid['precipitation snow [m SWE s^-1]_sd0.45'],label='snow density=0.45 kg m^-3')
f2_ax6.set_ylabel('[m SWE s^-1]')
f2_ax6.set_xlabel('[Number of days]',fontsize=14)
f2_ax6.legend()
#f2_ax6.grid(True)

plt.savefig("CalibValid_InputData_c.jpg", dpi=300)

# %% [markdown]
# ### 2. Parameters
# - Every case had a parameter file and parameter group file which gave PEST the list of parameters that it needs to "wiggle" within the range in order to determine the parameter set with the lowest objective function. Of course it is a non-unique parameter set. The optimum parameter set might vary if the parameter initial values or ranges changes.

# %%
# Read input parameter data 

Case1_par_data = pd.read_csv('..\\5_calib\\Case1_calib\\Case1_rw.demo\\Case1_par_data.csv',sep=',',index_col=0)
Case2_par_data = pd.read_csv('..\\5_calib\\Case2_calib\\Case2_rw.demo\\Case2_par_data.csv',sep=',',index_col=0)
Case3_par_data = pd.read_csv('..\\5_calib\\Case3_calib\\Case3_rw_cl.demo\\Case3_par_data.csv',sep=',',index_col=0)

# Dropping unnecessary columns

Case1_par_data = Case1_par_data.drop(['partrans','parchglim','pargp','scale','offset','dercom'],axis=1)
Case2_par_data = Case2_par_data.drop(['partrans','parchglim','pargp','scale','offset','dercom'],axis=1)
Case3_par_data = Case3_par_data.drop(['partrans','parchglim','pargp','scale','offset','dercom'],axis=1)

# Renaming the columns

Case1_par_data = Case1_par_data.rename(columns={"parval1":"Case1_inipar","parlbnd":"Case1_parlbnd","parubnd":"Case1_parubnd"})
Case2_par_data = Case2_par_data.rename(columns={"parval1":"Case2_inipar","parlbnd":"Case2_parlbnd","parubnd":"Case2_parubnd"})
Case3_par_data = Case3_par_data.rename(columns={"parval1":"Case3_inipar","parlbnd":"Case3_parlbnd","parubnd":"Case3_parubnd"})

# Combining all the three dataframes
Cases_par_data = pd.concat([Case1_par_data,Case2_par_data,Case3_par_data],axis=1)

Cases_par_data
# Out:
#          Case1_inipar  Case1_parlbnd  Case1_parubnd  Case2_inipar  \
# parnme
# alpha_p  1.000000e-02   2.500000e-03   1.750000e-02  1.000000e-02
# alpha_m  1.824914e-03   4.562286e-04   3.193600e-03  1.825000e-03
# n_p      2.050000e+00   1.025000e+00   3.075000e+00  1.500000e+00
# n_m      2.050000e+00   1.025000e+00   3.075000e+00           NaN
# wr_p     2.243241e-01   5.608104e-02   3.925673e-01  1.000000e-01
# wr_m     1.594881e-01   3.987202e-02   2.791041e-01           NaN
# tcs_p    4.395766e-01   1.098942e-01   7.692591e-01           NaN
# tcs_m    9.521051e-01   2.380263e-01   1.666184e+00           NaN
# tcd_p    1.010234e-01   2.525585e-02   1.767910e-01           NaN
# tcd_m    9.844054e-01   2.461014e-01   1.722710e+00           NaN
# af_p     1.505114e+00   3.762785e-01   2.633950e+00           NaN
# af_m     1.499389e+00   3.748473e-01   2.623931e+00           NaN
# auf_p    4.869354e-01   1.217339e-01   8.521370e-01           NaN
# ...

# %%
### Extracting the best parameter datasets

Case1_best_par = pd.read_csv('..\\5_calib\\Final_comp_cases_data\\best_params_Case1_rw.csv',sep=',',index_col=0)
Case2_best_par = pd.read_csv('..\\5_calib\\Final_comp_cases_data\\best_params_Case2_rw.csv',sep=',',index_col=0)
Case3_best_par = pd.read_csv('..\\5_calib\\Final_comp_cases_data\\best_params_Case3_rw.csv',sep=',',index_col=0)

Case1_best_par = Case1_best_par.rename(columns={"4":"Case1_bestpar"})
Case2_best_par = Case2_best_par.rename(columns={"14":"Case2_bestpar"})
Case3_best_par = Case3_best_par.rename(columns={"6":"Case3_bestpar"})

# Combining all the best parameter datasets
Cases_best_par = pd.concat([Case1_best_par, Case2_best_par, Case3_best_par],axis=1)

# Combining the best parameter dataset with all the parameter datasets

Cases_par_data_all = pd.concat([Cases_par_data, Cases_best_par],axis=1)

Cases_par_data_all
# Out:
#          Case1_inipar  Case1_parlbnd  Case1_parubnd  Case2_inipar  \
# alpha_p  1.000000e-02   2.500000e-03   1.750000e-02  1.000000e-02
# alpha_m  1.824914e-03   4.562286e-04   3.193600e-03  1.825000e-03
# n_p      2.050000e+00   1.025000e+00   3.075000e+00  1.500000e+00
# n_m      2.050000e+00   1.025000e+00   3.075000e+00           NaN
# wr_p     2.243241e-01   5.608104e-02   3.925673e-01  1.000000e-01
# wr_m     1.594881e-01   3.987202e-02   2.791041e-01           NaN
# tcs_p    4.395766e-01   1.098942e-01   7.692591e-01           NaN
# tcs_m    9.521051e-01   2.380263e-01   1.666184e+00           NaN
# tcd_p    1.010234e-01   2.525585e-02   1.767910e-01           NaN
# tcd_m    9.844054e-01   2.461014e-01   1.722710e+00           NaN
# af_p     1.505114e+00   3.762785e-01   2.633950e+00           NaN
# af_m     1.499389e+00   3.748473e-01   2.623931e+00           NaN
# auf_p    4.869354e-01   1.217339e-01   8.521370e-01           NaN
# ...

# %%
# Storing the table as png

dfi.export(Cases_par_data_all,'Tables_data/Cases_par_data_all.png')

# %%
# Storing the case results 

Cases_par_data_all.to_csv("Tables_data/Cases_par_data_all.csv",sep=",")

# %% [markdown]
# ### 3. Results

# %% [markdown]
# #### 3.1 Validation
# ##### 3.1.1 Subsurface temperature and moisture

# %%
# Reading the observations - 2019
df_obs_AWS = pd.read_csv('../1_data_prep/Final_OutputData_4yrs/Validate_outputdata_2019.csv',sep='\t')
df_obs_AWS.head()
# Out:
#     TIMESTAMP  Soil moisture at - 0.04 m (%)  Soil moisture at - 0.1 m (%)  \
# 0  2019-01-01                       6.423472                      7.538778
# 1  2019-01-02                       6.463458                      7.577208
# 2  2019-01-03                       6.458368                      7.578368
# 3  2019-01-04                       6.441076                      7.562042
# 4  2019-01-05                       6.434840                      7.551556
#
#    Soil moisture at - 0.2 m (%)  Soil moisture at - 0.4 m (%)  \
# 0                      8.086528                      8.609306
# 1                      8.120833                      8.615139
# 2                      8.129028                      8.620347
# 3                      8.118333                      8.615000
# 4                      8.103681                      8.597500
#
#    Soil moisture at - 0.8 m (%)  Soil moisture at - 1.2 m (%)  \
# 0                      5.178132                      3.371944
# ...

# %%
# Reading the observations - 2017
df_obs_AWS_III = pd.read_csv('../1_data_prep/Final_OutputData_Case3/Valid_outputdata_Case3_2017.csv',sep='\t')
df_obs_AWS_III.head()
# Out:
#     TIMESTAMP  Soil moisture at - 0.04 m (%)  Soil moisture at - 0.1 m (%)  \
# 0  2017-01-01                       8.001889                      8.352500
# 1  2017-01-02                       8.008944                      8.363681
# 2  2017-01-03                       8.001986                      8.356250
# 3  2017-01-04                       8.016035                      8.365417
# 4  2017-01-05                       8.037118                      8.386875
#
#    Soil moisture at - 0.2 m (%)  Soil moisture at - 0.4 m (%)  \
# 0                      8.502500                      8.952083
# 1                      8.515347                      8.959236
# 2                      8.513264                      8.958819
# 3                      8.515694                      8.953472
# 4                      8.527569                      8.957500
#
#    Soil moisture at - 0.8 m (%)  Soil moisture at - 1.2 m (%)  \
# 0                      5.408938                      3.765458
# ...

# %%
# Reading the results

case1_obs = pd.read_csv('../6_valid/Case1_valid.demo/observations.dat',skiprows=190,sep=' ')
case2_obs = pd.read_csv('../6_valid/Case2_valid.demo/observations.dat',skiprows=262,sep=' ')
case3_obs = pd.read_csv('../6_valid/Case3_valid.demo/observations.dat',skiprows=220,sep=' ')


case1_obs.head()
# Out:
#    time [s]  point -0.04 temperature [K]  point -0.1 temperature [K]  \
# 0       0.0                   258.367326                  259.833831
# 1   86400.0                   258.085749                  259.926209
# 2  172800.0                   257.808060                  259.854924
# 3  259200.0                   257.392283                  259.631060
# 4  345600.0                   257.022062                  259.381274
#
#    point -0.2 temperature [K]  point -0.4 temperature [K]  \
# 0                  261.545082                  262.858144
# 1                  261.941854                  263.098426
# 2                  261.986541                  263.159634
# 3                  261.907985                  263.130794
# 4                  261.775674                  263.048973
#
#    point -0.8 temperature [K]  point -1.2 temperature [K]  \
# 0                  264.988292                  266.860213
# 1                  264.941297                  266.711694
# ...

# %%
# Converting seconds to days

case1_obs['time [days]'] = case1_obs['time [s]']/86400
case2_obs['time [days]'] = case2_obs['time [s]']/86400
case3_obs['time [days]'] = case3_obs['time [s]']/86400

# %%
### Temperature from Kelvin to Degree celcius

depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

for i, depth in enumerate(depths):
    case1_obs[f'Soil temperature at - {depth} m (°C)'] = case1_obs[f'point -{depth} temperature [K]'] - 273.15
    case2_obs[f'Soil temperature at - {depth} m (°C)'] = case2_obs[f'point -{depth} temperature [K]'] - 273.15
    case3_obs[f'Soil temperature at - {depth} m (°C)'] = case3_obs[f'point -{depth} temperature [K]'] - 273.15


case1_obs.head()
# Out:
#    time [s]  point -0.04 temperature [K]  point -0.1 temperature [K]  \
# 0       0.0                   258.367326                  259.833831
# 1   86400.0                   258.085749                  259.926209
# 2  172800.0                   257.808060                  259.854924
# 3  259200.0                   257.392283                  259.631060
# 4  345600.0                   257.022062                  259.381274
#
#    point -0.2 temperature [K]  point -0.4 temperature [K]  \
# 0                  261.545082                  262.858144
# 1                  261.941854                  263.098426
# 2                  261.986541                  263.159634
# 3                  261.907985                  263.130794
# 4                  261.775674                  263.048973
#
#    point -0.8 temperature [K]  point -1.2 temperature [K]  \
# 0                  264.988292                  266.860213
# 1                  264.941297                  266.711694
# ...

# %%
### Saturation of liquid to Volumetric Water Content (VWC - %)

depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

depth_peat = 0.3

poro_peat_1 = 0.63840773749824
poro_mineral_1 = 0.48163834735695

poro_peat_2 = 0.42152389790647
poro_mineral_2 = 0.36232061622228

poro_peat_3 = 0.64661880775129
poro_mineral_3 = 0.48321096221786



for i, depth in enumerate(depths):
    if depth < depth_peat:
        case1_obs[f'Soil moisture at - {depth} m (%)'] = case1_obs[f'point -{depth} saturation liquid']*(poro_peat_1*100)
        case2_obs[f'Soil moisture at - {depth} m (%)'] = case2_obs[f'point -{depth} saturation liquid']*(poro_peat_2*100)
        case3_obs[f'Soil moisture at - {depth} m (%)'] = case3_obs[f'point -{depth} saturation liquid']*(poro_peat_3*100)
    else:
        case1_obs[f'Soil moisture at - {depth} m (%)'] = case1_obs[f'point -{depth} saturation liquid']*(poro_mineral_1*100)
        case2_obs[f'Soil moisture at - {depth} m (%)'] = case2_obs[f'point -{depth} saturation liquid']*(poro_mineral_2*100)
        case3_obs[f'Soil moisture at - {depth} m (%)'] = case3_obs[f'point -{depth} saturation liquid']*(poro_mineral_3*100)

# %%
### Plotting the final results (mesured vs simulated) along with the parameters:
### Plotting the temperature for different alpha values at depth 0.01 m
fig2 = plt.figure(figsize=(18,15), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=6, height_ratios=[1,1,1,1,1,1], figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
f2_ax5 = fig2.add_subplot(spec2[4, 0])
f2_ax6 = fig2.add_subplot(spec2[5, 0])

#fig2.suptitle(f'Temperature and soil moisture at different depths', fontsize=20)


depths = [0.04, 0.2, 0.4, 0.8, 1.2, 1.6]


for j, depth in enumerate(depths):
    
    locals()['f2_ax'+str(j+1)].plot(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'], 'k', label=f'measured')
    locals()['f2_ax'+str(j+1)].plot(case1_obs[f'Soil temperature at - {depth} m (°C)'], '#377eb8', label=f'T-Case 1')
    locals()['f2_ax'+str(j+1)].plot(case2_obs[f'Soil temperature at - {depth} m (°C)'], '#e41a1c', label=f'T-Case 2')
    locals()['f2_ax'+str(j+1)].plot(case3_obs[f'Soil temperature at - {depth} m (°C)'], '#4daf4a', label=f'T-Case 3')
    #locals()['f2_ax'+str(j+1)].plot(time_period, temp_sim_4[x:x+1096].values, 'g', label=f'T-Case 3')
    locals()['f2_ax'+str(j+1)].set_title(f'Depth - {depth} m', fontsize=20)
    #locals()['f2_ax'+str(j+1)].grid(True)
    #locals()['f2_ax'+str(j+1)].legend(fontsize=14)
    locals()['f2_ax'+str(j+1)].set_ylim(-20,10)
    
    ax2 = locals()['f2_ax'+str(j+1)].twinx()
    
    color = 'tab:blue'
    ax2.plot(df_obs_AWS[f'Soil moisture at - {depth} m (%)'], 'k--', label=f'measured')
    ax2.plot(case1_obs[f'Soil moisture at - {depth} m (%)'], '#377eb8', linestyle='dashed', label=f'M-Case 1')
    ax2.plot(case2_obs[f'Soil moisture at - {depth} m (%)'], '#e41a1c', linestyle='dashed', label=f'M-Case 2')
    ax2.plot(case3_obs[f'Soil moisture at - {depth} m (%)'], '#4daf4a', linestyle='dashed', label=f'M-Case 3')
    #ax2.plot(time_period, mois_sim_4[x:x+1096].values, 'g--', label=f'M-Case 3')
    ax2.set_ylim(0,100)
    
    

    for label in (locals()['f2_ax'+str(j+1)].get_xticklabels() + locals()['f2_ax'+str(j+1)].get_yticklabels()):
        label.set_fontsize(13)
    for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
        label.set_fontsize(13)
    
    if j == 2:
        locals()['f2_ax'+str(j+1)].legend(fontsize=14, loc=2)  
        locals()['f2_ax'+str(j+1)].set_ylabel('Temperature (°C)', fontsize=25)
        #locals()['f2_ax'+str(j+1)].set_xlabel('Days', fontsize=20)

        ax2.legend(fontsize=14, loc=1)  
        ax2.set_ylabel('VWC (%)', fontsize=25)

f2_ax6.set_xlabel('Number of days', fontsize=25)

plt.savefig('Valid_Tempmois_results.jpg',dpi=300)

# %%
### Plotting the final results (mesured vs simulated) along with the parameters:
### Plotting the temperature for different alpha values at depth 0.01 m
fig2 = plt.figure(figsize=(18,10), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=3, height_ratios=[1,1,1], figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
#f2_ax4 = fig2.add_subplot(spec2[3, 0])
#f2_ax5 = fig2.add_subplot(spec2[4, 0])
#f2_ax6 = fig2.add_subplot(spec2[5, 0])

#fig2.suptitle(f'Measured and simulated temperature and volumetric water content at different depths', fontsize=24)


depths = [0.1, 0.4, 1.6]


for j, depth in enumerate(depths):
    
    locals()['f2_ax'+str(j+1)].plot(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'], 'k', label=f'measured')
    locals()['f2_ax'+str(j+1)].plot(case1_obs[f'Soil temperature at - {depth} m (°C)'], '#377eb8', label=f'T-Case 1')
    locals()['f2_ax'+str(j+1)].plot(case2_obs[f'Soil temperature at - {depth} m (°C)'], '#e41a1c', label=f'T-Case 2')
    locals()['f2_ax'+str(j+1)].plot(case3_obs[f'Soil temperature at - {depth} m (°C)'], '#4daf4a', label=f'T-Case 3')
    #locals()['f2_ax'+str(j+1)].plot(time_period, temp_sim_4[x:x+1096].values, 'g', label=f'T-Case 3')
    locals()['f2_ax'+str(j+1)].set_title(f'Depth - {depth} m', fontsize=20)
    #locals()['f2_ax'+str(j+1)].grid(True)
    #locals()['f2_ax'+str(j+1)].legend(fontsize=14)
    locals()['f2_ax'+str(j+1)].set_ylim(-20,10)
    
    ax2 = locals()['f2_ax'+str(j+1)].twinx()
    
    color = 'tab:blue'
    ax2.plot(df_obs_AWS[f'Soil moisture at - {depth} m (%)'], 'k--', label=f'measured')
    ax2.plot(case1_obs[f'Soil moisture at - {depth} m (%)'], '#377eb8', linestyle='dashed', label=f'M-Case 1')
    ax2.plot(case2_obs[f'Soil moisture at - {depth} m (%)'], '#e41a1c', linestyle='dashed', label=f'M-Case 2')
    ax2.plot(case3_obs[f'Soil moisture at - {depth} m (%)'], '#4daf4a', linestyle='dashed', label=f'M-Case 3')
    #ax2.plot(time_period, mois_sim_4[x:x+1096].values, 'g--', label=f'M-Case 3')
    ax2.set_ylim(0,100)
    
    

    for label in (locals()['f2_ax'+str(j+1)].get_xticklabels() + locals()['f2_ax'+str(j+1)].get_yticklabels()):
        label.set_fontsize(16)
    for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
        label.set_fontsize(16)
    
    if j == 1:
        locals()['f2_ax'+str(j+1)].legend(fontsize=16, loc=2)  
        locals()['f2_ax'+str(j+1)].set_ylabel('Temperature (°C)', fontsize=25)
        #locals()['f2_ax'+str(j+1)].set_xlabel('Days', fontsize=20)

        ax2.legend(fontsize=16, loc=1)  
        ax2.set_ylabel('Volumtric water content (%)', fontsize=25)

f2_ax3.set_xlabel('Number of days', fontsize=20)

plt.savefig('Valid_Tempmois_results_concise.jpg',dpi=300)

# %% [markdown]
# ##### 3.1.2 Thaw depth, surface-subsurface flux, Evaporation rate

# %%
### Plotting the final results (mesured vs simulated) along with the parameters:
fig2 = plt.figure(figsize=(15,8), constrained_layout=True)
spec2 = gridspec.GridSpec(ncols=1, nrows=4, height_ratios=[1,1,1,1], figure=fig2)
f2_ax1 = fig2.add_subplot(spec2[0, 0])
f2_ax2 = fig2.add_subplot(spec2[1, 0])
f2_ax3 = fig2.add_subplot(spec2[2, 0])
f2_ax4 = fig2.add_subplot(spec2[3, 0])
#f2_ax5 = fig2.add_subplot(spec2[4, 0])

#f2_ax3.bar(data_AWS_input_CalibValid.index,data_AWS_input_CalibValid['precipitation rain [m s^-1]'],label='precipitation rain [m s^-1]')

# Plotting precipitation rate
f2_ax1.set_title('Precipitation rain [m s^-1] and air temperature [K]', fontsize=15)
#plt.plot(case1_obs['point -0.01 temperature [K]'][:1000],label='0.01 m')
f2_ax1.bar(case3_obs.index, case3_obs['precipitation rain [m s^-1]'])
f2_ax1.set_ylabel('[m s^-1]', fontsize=15)
ax2 = f2_ax1.twinx()
ax2.plot(data_AWS_input_CalibValid['air temperature [K]']['2019'].values - 273.15,'#ff7f00')
ax2.set_ylabel('Temperature [°C]', fontsize=12)


# Plotting Evaporation rate
f2_ax2.set_title('Evaporation rate [m s^-1]', fontsize=15)
#plt.plot(case1_obs['point -0.01 temperature [K]'][:1000],label='0.01 m')
f2_ax2.plot(case2_obs['evaporation rate [m s^-1]'], '#e41a1c',label='Case 2')
#f2_ax2.plot(case3_obs['evaporation rate [m s^-1]'], '#4daf4a',label='Case 3')
f2_ax2.set_ylabel('[m s^-1]', fontsize=15)
#f2_ax2.legend(loc=1)


# Plotting surface-subsurface flux [mol s^-1]
f2_ax3.set_title('Surface-subsurface flux [mol s^-1]', fontsize=15)
f2_ax3.plot(case2_obs['surface-subsurface flux [mol s^-1]'], '#e41a1c',label='Case 2')
#f2_ax3.plot(case3_obs['surface-subsurface flux [mol s^-1]'], '#4daf4a',label='Case 3')
f2_ax3.set_ylabel('[mol s^-1]', fontsize=15)
#f2_ax3.legend(loc=1)

# Plotting surface-subsurface flux [mol s^-1]
f2_ax4.set_title('Thaw depth [m]', fontsize=15)
#plt.plot(case1_obs['point -0.01 temperature [K]'][:1000],label='0.01 m')
#f2_ax4.plot(case1_obs['thaw depth [m]'], '#377eb8', linestyle='dashed',label='Case 1')
f2_ax4.plot(case2_obs['thaw depth [m]'], '#e41a1c',label='Case 2')
#f2_ax4.plot(case3_obs['thaw depth [m]'], '#4daf4a',label='Case 3')
f2_ax4.set_ylabel('[m]', fontsize=15)
#f2_ax4.legend(loc=1)

f2_ax4.set_xlabel('Number of days', fontsize=15)

# Plotting saturation of liquid
#f2_ax5.set_title('Soil moisture at different depths [%]', fontsize=15)
#plt.plot(case1_obs['point -0.01 temperature [K]'][:1000],label='0.01 m')
#f2_ax5.plot(case2_obs['point -0.8 saturation liquid'],label='Case 2 - 0.8 m')
#f2_ax5.plot(case2_obs['point -1.2 saturation liquid'],label='Case 2 - 1.2 m')
#f2_ax5.plot(case3_obs['point -0.8 saturation liquid'],label='Case 3 - 0.8 m')
#f2_ax5.plot(case3_obs['point -1.2 saturation liquid'],label='Case 3 - 1.2 m')
#f2_ax5.legend(loc=1)

plt.savefig('Valid_Case2_waterflux.jpg',dpi=300)

# %% [markdown]
# Comments:
# * The thaw depth has increased during the summer for case 2 - associated with increase in temperature and influx of water?
# * Do we also plot latent heat, sensible heat, net radiation, transpiration rate, snow melt, .. ?

# %% [markdown]
# #### 3.2 RMSE, R2, NSE

# %%
# Defining the dataframe

depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

rmse_df_case1 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])
rmse_df_case2 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])
rmse_df_case3 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])

# %%
df_obs_AWS_III.head()
# Out:
#     TIMESTAMP  Soil moisture at - 0.04 m (%)  Soil moisture at - 0.1 m (%)  \
# 0  2017-01-01                       8.001889                      8.352500
# 1  2017-01-02                       8.008944                      8.363681
# 2  2017-01-03                       8.001986                      8.356250
# 3  2017-01-04                       8.016035                      8.365417
# 4  2017-01-05                       8.037118                      8.386875
#
#    Soil moisture at - 0.2 m (%)  Soil moisture at - 0.4 m (%)  \
# 0                      8.502500                      8.952083
# 1                      8.515347                      8.959236
# 2                      8.513264                      8.958819
# 3                      8.515694                      8.953472
# 4                      8.527569                      8.957500
#
#    Soil moisture at - 0.8 m (%)  Soil moisture at - 1.2 m (%)  \
# 0                      5.408938                      3.765458
# ...

# %%
depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

# Note: Case 1 and Case 2 is for 2019
# Note: Case 3 is for 2017

# Calculating the RMSE for temperature and moisture
for j, depth in enumerate(depths):
    rmse_df_case1.iloc[j,0] = np.mean(np.power(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] - case1_obs[f'Soil temperature at - {depth} m (°C)'],2))
    rmse_df_case2.iloc[j,0] = np.mean(np.power(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] - case2_obs[f'Soil temperature at - {depth} m (°C)'],2))
    rmse_df_case3.iloc[j,0] = np.mean(np.power(df_obs_AWS_III[f'Soil temperature at - {depth} m (°C)'] - case3_obs[f'Soil temperature at - {depth} m (°C)'],2))
    
    rmse_df_case1.iloc[j,1] = np.mean(np.power(df_obs_AWS[f'Soil moisture at - {depth} m (%)'] - case1_obs[f'Soil moisture at - {depth} m (%)'],2))
    rmse_df_case2.iloc[j,1] = np.mean(np.power(df_obs_AWS[f'Soil moisture at - {depth} m (%)'] - case2_obs[f'Soil moisture at - {depth} m (%)'],2))
    rmse_df_case3.iloc[j,1] = np.mean(np.power(df_obs_AWS_III[f'Soil moisture at - {depth} m (%)'] - case3_obs[f'Soil moisture at - {depth} m (%)'],2))

# %%
rmse_df_case2
# Out:
#      Temperature   Moisture
# 0.04   10.788844   82.97729
# 0.10    9.403814  60.540903
# 0.20    9.061121  94.902433
# 0.40    8.558497   25.68617
# 0.80    7.450337   22.59116
# 1.20    4.118279  23.213884
# 1.60    4.049678  19.764928

# %% [markdown]
# ##### $R^2$ (Coefficient of determination)
#
# Link: https://en.wikipedia.org/wiki/Coefficient_of_determination
#
# $$R^2 = 1 - \frac{RSS}{TSS}$$
#
# Where RSS is the sum of squared residuals, TSS is the total sum of squares (Related to the variance of the data)
#
# Let y be the measured values and x be the simulated values (after calibration)
#
# $$\bar{y} = \frac{1}{n}\sum_{i=1}^{n} (y_i)$$
#
# $$RSS = \sum_{i=1}^{n} (y_i - x_i)^2$$
#
# $$TSS = \sum_{i=1}^{n} (y_i - \bar{y})^2$$
#
# In the best case, the modeled values exactly match the observed values, which results in TSS = 0 and $ R^{2}=1$. A baseline model, which always predicts $\bar{y}$, will have  $R^{2}=0$. Models that have worse predictions than this baseline will have a negative $R^{2}$.

# %%
# Defining the dataframe

depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

coef_det_df_case1 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])
coef_det_df_case2 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])
coef_det_df_case3 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])

# %%
# Test
depth = 1.2

RSS = (np.sum(np.power(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] - case1_obs[f'Soil temperature at - {depth} m (°C)'],2)))
TSS = (np.sum(np.power(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] - df_obs_AWS[f'Soil temperature at - {depth} m (°C)'].mean(),2)))

coef_det = 1 - RSS/TSS

coef_det
# Out:
# 0.8156070040151424

# %%
depth = 0.1
1 - (np.sum(np.power(df_obs_AWS[f'Soil moisture at - {depth} m (%)'] - case1_obs[f'Soil moisture at - {depth} m (%)'],2)))/(np.sum(np.power(df_obs_AWS[f'Soil moisture at - {depth} m (%)'] - df_obs_AWS[f'Soil moisture at - {depth} m (%)'].mean(),2)))
# Out:
# 0.06564752466446366

# %%
coef_det_df_case1
# Out:
#      Temperature  Moisture
# 0.04    0.966879  0.064524
# 0.10    0.936781  0.065648
# 0.20    0.867452  0.138155
# 0.40    0.843631 -0.084719
# 0.80     0.80821 -0.314615
# 1.20    0.815607 -0.382747
# 1.60    0.778309 -0.081745

# %%
depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

# Note: Case 1 and Case 2 is for 2019
# Note: Case 3 is for 2017

# Calculating the RMSE for temperature and moisture
for j, depth in enumerate(depths):
    # Temperature
    coef_det_df_case1.iloc[j,0] = 1 - (np.sum(np.power(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] - case1_obs[f'Soil temperature at - {depth} m (°C)'],2)))/(np.sum(np.power(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] - df_obs_AWS[f'Soil temperature at - {depth} m (°C)'].mean(),2)))
    coef_det_df_case2.iloc[j,0] = 1 - (np.sum(np.power(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] - case2_obs[f'Soil temperature at - {depth} m (°C)'],2)))/(np.sum(np.power(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] - df_obs_AWS[f'Soil temperature at - {depth} m (°C)'].mean(),2)))
    coef_det_df_case3.iloc[j,0] = 1 - (np.sum(np.power(df_obs_AWS_III[f'Soil temperature at - {depth} m (°C)'] - case3_obs[f'Soil temperature at - {depth} m (°C)'],2)))/(np.sum(np.power(df_obs_AWS_III[f'Soil temperature at - {depth} m (°C)'] - df_obs_AWS_III[f'Soil temperature at - {depth} m (°C)'].mean(),2)))
    
    # Moisture
    coef_det_df_case1.iloc[j,1] = 1 - (np.sum(np.power(df_obs_AWS[f'Soil moisture at - {depth} m (%)'] - case1_obs[f'Soil moisture at - {depth} m (%)'],2)))/(np.sum(np.power(df_obs_AWS[f'Soil moisture at - {depth} m (%)'] - df_obs_AWS[f'Soil moisture at - {depth} m (%)'].mean(),2)))
    coef_det_df_case2.iloc[j,1] = 1 - (np.sum(np.power(df_obs_AWS[f'Soil moisture at - {depth} m (%)'] - case2_obs[f'Soil moisture at - {depth} m (%)'],2)))/(np.sum(np.power(df_obs_AWS[f'Soil moisture at - {depth} m (%)'] - df_obs_AWS[f'Soil moisture at - {depth} m (%)'].mean(),2)))
    coef_det_df_case3.iloc[j,1] = 1 - (np.sum(np.power(df_obs_AWS_III[f'Soil moisture at - {depth} m (%)'] - case3_obs[f'Soil moisture at - {depth} m (%)'],2)))/(np.sum(np.power(df_obs_AWS_III[f'Soil moisture at - {depth} m (%)'] - df_obs_AWS_III[f'Soil moisture at - {depth} m (%)'].mean(),2)))

# %%
coef_det_df_case3
# Out:
#      Temperature  Moisture
# 0.04     0.36196 -0.611595
# 0.10    0.393583 -0.690887
# 0.20    0.404347 -0.684636
# 0.40    0.450129 -0.890766
# 0.80    0.467537 -0.093659
# 1.20    0.534653 -0.219242
# 1.60    0.526919 -0.056637

# %%
fig, ax = plt.subplots(figsize=(10, 8))

#plt.figure(figsize=(20, 12))

# Case 1
ax.plot(coef_det_df_case1.iloc[:,0], -coef_det_df_case1.index,'#377eb8', label=f'T-Case 1')
ax.plot(coef_det_df_case1.iloc[:,1], -coef_det_df_case1.index,'#377eb8', linestyle='dashed', label=f'M-Case 1')

# Case 2
ax.plot(coef_det_df_case2.iloc[:,0], -coef_det_df_case1.index,'#e41a1c', label=f'T-Case 2')
ax.plot(coef_det_df_case2.iloc[:,1], -coef_det_df_case1.index,'#e41a1c', linestyle='dashed',label=f'M-Case 2')

# Case 3
ax.plot(coef_det_df_case3.iloc[:,0], -coef_det_df_case1.index,'#4daf4a', label=f'T-Case 3')
ax.plot(coef_det_df_case3.iloc[:,1], -coef_det_df_case1.index,'#4daf4a', linestyle='dashed',label=f'M-Case 3')


#for i, name in enumerate(cf_names):
#    ax.plot(locals()[f'obj_fn_{i+1}']['total_phi'],label=f'{name}')
    
#ax.set_title('Nash-Sutcliffe Model efficiency (coef_det) coefficient Vs Depth', fontsize=15)
ax.set_ylabel('Depth (in m)', fontsize=20)
ax.set_xlabel('Coefficient of determination (R^2)', fontsize=20)
ax.grid(b=True)
ax.legend(fontsize=16)

# We change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', labelsize=15)
ax.tick_params(axis='both', which='minor', labelsize=15)


#plt.savefig('Valid_coef_det.jpg',dpi=300)

# %% [markdown]
# Comments: It is the same as NSF, however the observed and simulated values in NSF is better represented. In R^2, the there is a ependency between y and x (which does not exist in NSF). - https://stats.stackexchange.com/questions/185898/difference-between-nash-sutcliffe-efficiency-and-coefficient-of-determination

# %% [markdown]
# #### NSF
#
# $$R^2 = 1 - \frac{RSS}{TSS}$$
#
# Where RSS is the sum of squared residuals, TSS is the total sum of squares (Related to the variance of the data)
#
# Let y be the measured values and x be the simulated values (after calibration)
#
# $$\bar{y} = \frac{1}{n}\sum_{i=1}^{n} (y_i)$$
#
# $$RSS = \sum_{i=1}^{n} (y_i - x_i)^2$$
#
# $$TSS = \sum_{i=1}^{n} (y_i - \bar{y})^2$$
#
# In the best case, the modeled values exactly match the observed values, which results in TSS = 0 and $ R^{2}=1$. A baseline model, which always predicts $\bar{y}$, will have  $R^{2}=0$. Models that have worse predictions than this baseline will have a negative $R^{2}$.

# %%
# Defining the dataframe

depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

nse_df_case1 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])
nse_df_case2 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])
nse_df_case3 = pd.DataFrame(index=depths,columns=['Temperature','Moisture'])

# %%
# Defining a Nash-Sutcliffe coefficient
def nse(targets, predictions):
    nse_value = (1-(np.sum((predictions-targets)**2)/np.sum((targets-np.mean(targets))**2)))
    return nse_value

# %%
# Test
nse(df_obs_AWS[f'Soil temperature at - 1.6 m (°C)'], case2_obs[f'Soil temperature at - 1.6 m (°C)'])
# Out:
# 0.705265046578798

# %%
depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

# Note: Case 1 and Case 2 is for 2019
# Note: Case 3 is for 2017

# Calculating the RMSE for temperature
for j, depth in enumerate(depths):
    nse_df_case1.iloc[j,0] = nse(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'], case1_obs[f'Soil temperature at - {depth} m (°C)'])
    nse_df_case2.iloc[j,0] = nse(df_obs_AWS[f'Soil temperature at - {depth} m (°C)'], case2_obs[f'Soil temperature at - {depth} m (°C)'])
    nse_df_case3.iloc[j,0] = nse(df_obs_AWS_III[f'Soil temperature at - {depth} m (°C)'], case3_obs[f'Soil temperature at - {depth} m (°C)'])
    
    nse_df_case1.iloc[j,1] = nse(df_obs_AWS[f'Soil moisture at - {depth} m (%)'], case1_obs[f'Soil moisture at - {depth} m (%)'])
    nse_df_case2.iloc[j,1] = nse(df_obs_AWS[f'Soil moisture at - {depth} m (%)'], case2_obs[f'Soil moisture at - {depth} m (%)'])
    nse_df_case3.iloc[j,1] = nse(df_obs_AWS_III[f'Soil moisture at - {depth} m (%)'], case3_obs[f'Soil moisture at - {depth} m (%)'])

# %%
nse_df_case2
# Out:
#      Temperature  Moisture
# 0.04    0.792586  0.558384
# 0.10    0.816855  0.657359
# 0.20    0.799544  0.385301
# 0.40     0.76881  0.786355
# 0.80    0.734819  0.115844
# 1.20    0.750307 -2.042261
# 1.60    0.705265 -0.049911

# %%
fig, ax = plt.subplots(figsize=(10, 8))

#plt.figure(figsize=(20, 12))

# Case 1
ax.plot(nse_df_case1.iloc[:,0], -nse_df_case1.index,'#377eb8', label=f'T-Case 1')
ax.plot(nse_df_case1.iloc[:,1], -nse_df_case1.index,'#377eb8', linestyle='dashed', label=f'M-Case 1')

# Case 2
ax.plot(nse_df_case2.iloc[:,0], -nse_df_case1.index,'#e41a1c', label=f'T-Case 2')
ax.plot(nse_df_case2.iloc[:,1], -nse_df_case1.index,'#e41a1c', linestyle='dashed',label=f'M-Case 2')

# Case 3
ax.plot(nse_df_case3.iloc[:,0], -nse_df_case1.index,'#4daf4a', label=f'T-Case 3')
ax.plot(nse_df_case3.iloc[:,1], -nse_df_case1.index,'#4daf4a', linestyle='dashed',label=f'M-Case 3')


#for i, name in enumerate(cf_names):
#    ax.plot(locals()[f'obj_fn_{i+1}']['total_phi'],label=f'{name}')
    
#ax.set_title('Nash-Sutcliffe Model efficiency (NSE) coefficient Vs Depth', fontsize=15)
ax.set_ylabel('Depth (in m)', fontsize=20)
ax.set_xlabel('Nash-Sutcliffe Model efficiency (NSE)', fontsize=20)
ax.grid(b=True)
ax.legend(fontsize=16)

# We change the fontsize of minor ticks label 
ax.tick_params(axis='both', which='major', labelsize=15)
ax.tick_params(axis='both', which='minor', labelsize=15)


plt.savefig('Valid_NSE.jpg',dpi=300,bbox_inches='tight')

# %%
### Renaming the dataframes and combining the three dataframes
nse_df_case1.rename(columns={'Temperature':'Case1_Temp','Moisture':'Case1_Mois'},inplace=True)
nse_df_case2.rename(columns={'Temperature':'Case2_Temp','Moisture':'Case2_Mois'},inplace=True)
nse_df_case3.rename(columns={'Temperature':'Case3_Temp','Moisture':'Case3_Mois'},inplace=True)

nse_df_cases = pd.concat([nse_df_case1,nse_df_case2,nse_df_case3],axis=1)
nse_df_cases
# Out:
#      Case1_Temp Case1_Mois Case2_Temp Case2_Mois Case3_Temp Case3_Mois
# 0.04   0.966879   0.064524   0.792586   0.558384    0.36196  -0.611595
# 0.10   0.936781   0.065648   0.816855   0.657359   0.393583  -0.690887
# 0.20   0.867452   0.138155   0.799544   0.385301   0.404347  -0.684636
# 0.40   0.843631  -0.084719    0.76881   0.786355   0.450129  -0.890766
# 0.80    0.80821  -0.314615   0.734819   0.115844   0.467537  -0.093659
# 1.20   0.815607  -0.382747   0.750307  -2.042261   0.534653  -0.219242
# 1.60   0.778309  -0.081745   0.705265  -0.049911   0.526919  -0.056637

# %%
### Exporting the tables as images and csv for recreating it later

dfi.export(nse_df_cases,'Tables_data/nse_df_cases.png')

# %%
nse_df_cases.to_csv('Tables_data/nse_df_cases.csv',sep=',')

# %%
nse_df_case1.mean()
# Out:
# Temperature    0.859553
# Moisture      -0.085071
# dtype: float64

# %%
nse_df_case2.mean()
# Out:
# Temperature    0.766884
# Moisture       0.058724
# dtype: float64

# %%
nse_df_case3.mean()
# Out:
# Temperature    0.448447
# Moisture      -0.463918
# dtype: float64

# %%
# Determining the mean for all cases

nse_df_mean = pd.DataFrame(columns=['Temperature','Moisture'],index=['Case 1','Case 2','Case 3'])

for i in np.arange(len(nse_df_mean)):
    nse_df_mean.iloc[i,:] = locals()['nse_df_case'+str(i+1)].mean()

nse_df_mean = nse_df_mean.astype('float')

nse_df_mean =  np.round(nse_df_mean,2)

nse_df_mean
# Out:
#         Temperature  Moisture
# Case 1         0.86     -0.09
# Case 2         0.77      0.06
# Case 3         0.45     -0.46

# %%
### Storing the tables as images for recreating it later

dfi.export(nse_df_case1,'sen_cases_log_t.png')

# %% [markdown]
# #### 3.3 Parameter sensitivity for calibration

# %%
# Read sensitivity data 

sen_cases = pd.read_csv('..\\5_calib\\Final_comp_cases_data\\sen_cases_all.csv',sep=',',index_col=0)

sen_cases
# Out:
#            alpha_p   alpha_m       n_p       n_m      wr_p     wr_m     tcs_p  \
# Case1_rw  0.000171  0.000334  0.000002  0.000001  0.000011  0.00001  0.000004
# Case2_rw  0.000049  0.000913  0.000002  0.000000  0.000007  0.00000  0.000000
# Case3_rw  0.000095  0.000113  0.000010  0.000000  0.000061  0.00000  0.000000
#
#              tcs_m     tcd_p         tcd_m  ...          af_m     auf_p  \
# Case1_rw  0.000001  0.000004  4.507250e-07  ...  1.706960e-07  0.000002
# Case2_rw  0.000000  0.000000  0.000000e+00  ...  0.000000e+00  0.000000
# Case3_rw  0.000000  0.000000  0.000000e+00  ...  0.000000e+00  0.000000
#
#                  auf_m     por_p     por_m    perm_p     perm_m         den_p  \
# Case1_rw  8.891470e-08  0.000005  0.000005  11837.00   356858.0  4.302220e-08
# Case2_rw  0.000000e+00  0.000010  0.000009  35767.40  3823440.0  0.000000e+00
# Case3_rw  0.000000e+00  0.000016  0.000018   3242.81  1275200.0  0.000000e+00
#
#                  den_m          b_bc
# ...

# %%
# Example
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
fig = plt.figure()
fig.set_size_inches(20,5)
ax = fig.add_axes([0,0,1,1])
#for
X = np.arange(len(sen_cases.columns)) # Number of parts to consider
x = len(sen_cases.index)

#ax.bar(X + 0.0, sen_cases.iloc[0,:], color='y', label=f'{cf_name_1}', width=0.2)
#ax.bar(X + 0.25, sen_cases.iloc[1,:], color='b', label=f'{cf_name_2}', width=0.2)
#ax.bar(X + 0.5, sen_cases.iloc[2,:], color='k', label=f'{cf_name_3}', width=0.2)
ax.bar(X + 0.0, sen_cases.iloc[0,:], color='tab:green', label='Case 1', width=0.2)
ax.bar(X + 0.25, sen_cases.iloc[1,:], color='tab:red', label='Case 2', width=0.2)
ax.bar(X + 0.5, sen_cases.iloc[2,:], color='tab:blue', label='Case 3', width=0.2)
#ax.bar(X + 0.75, sen_cases.iloc[3,:], color='g', label=f'{cf_name_4}', width=0.2)

#ax.bar(X + 0.25, si_mineral_temp.iloc[0,:],color='tab:brown', label='mineral', width=0.25)
#ax.bar(X + 0.5, si_bedrock_temp.iloc[0,:], color='k', label='bedrock', width=0.25)
major_ticks = np.arange(0, len(sen_cases.columns.values), 1)
ax.set_xticks(major_ticks)
labels = [item.get_text() for item in ax.get_xticklabels()]
labels = sen_cases.columns.values
ax.set_xticklabels(labels)
ax.legend(fontsize=14)
ax.set_ylabel('Sensitivity values', fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15.5)
ax.tick_params(axis='both', which='minor', labelsize=18)
ax.set_xlabel('Parameters', fontsize=30)
ax.grid(b=True)

# %% [markdown]
# Comments:
#
#     * Due to the high parameter senstivity ranges, the values cannot be adequately seen in the plot. Therefore we are log transforming the values.

# %%
# Converting the values in log scale - Need to convert the type to float
sen_cases_log = np.log(sen_cases.astype(float))
# If there are any infinity values, they need to be replaced by null values!
sen_cases_log.replace([np.inf, -np.inf], np.nan, inplace=True)
sen_cases_log.head()
# Out:
#            alpha_p   alpha_m        n_p        n_m       wr_p       wr_m  \
# Case1_rw -8.671411 -8.004672 -13.270910 -13.652865 -11.461938 -11.540222
# Case2_rw -9.913849 -6.998552 -13.403977        NaN -11.931702        NaN
# Case3_rw -9.261426 -9.086770 -11.469081        NaN  -9.711470        NaN
#
#              tcs_p      tcs_m      tcd_p      tcd_m  ...       af_m  \
# Case1_rw -12.51766 -13.754858 -12.489481 -14.612408  ... -15.583382
# Case2_rw       NaN        NaN        NaN        NaN  ...        NaN
# Case3_rw       NaN        NaN        NaN        NaN  ...        NaN
#
#               auf_p      auf_m      por_p      por_m     perm_p     perm_m  \
# Case1_rw -13.189904 -16.235588 -12.299674 -12.155954   9.378985  12.785093
# Case2_rw        NaN        NaN -11.483687 -11.670692  10.484792  15.156661
# Case3_rw        NaN        NaN -11.029512 -10.912206   8.084196  14.058614
#
#              den_p      den_m       b_bc
# Case1_rw -16.96155 -17.708422 -18.178072
# ...

# %%
# Example
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
fig = plt.figure()
fig.set_size_inches(20,5)
ax = fig.add_axes([0,0,1,1])
#for
X = np.arange(len(sen_cases.columns)) # Number of parts to consider
x = len(sen_cases_log.index)

ax.bar(X + 0.0, sen_cases_log.iloc[0,:], color='tab:green', label='Case 1', width=0.25)
ax.bar(X + 0.33, sen_cases_log.iloc[1,:], color='tab:red', label='Case 2', width=0.25)
ax.bar(X + 0.66, sen_cases_log.iloc[2,:], color='tab:blue', label='Case 3', width=0.25)
major_ticks = np.arange(0, len(sen_cases_log.columns.values), 1)
ax.set_xticks(major_ticks)
labels = [item.get_text() for item in ax.get_xticklabels()]
labels = sen_cases_log.columns.values
ax.set_xticklabels(labels)
ax.legend(fontsize=14)
ax.set_ylabel('Log sensitivity values', fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15.5)
ax.tick_params(axis='both', which='minor', labelsize=15)
ax.set_xlabel('Parameters', fontsize=25)
#ax.axhline(y=-11.5,color='k',linestyle='-.')
ax.grid(b='True',which='both')

plt.savefig('log_sen_cases.jpg',dpi=300, bbox_inches="tight")

# %%
# Example - To meet color blindness requirement
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
fig = plt.figure()
fig.set_size_inches(20,5)
ax = fig.add_axes([0,0,1,1])
#for
X = np.arange(len(sen_cases.columns)) # Number of parts to consider
x = len(sen_cases_log.index)

ax.bar(X + 0.0, sen_cases_log.iloc[0,:], color='tab:green', label='Case 1', fill=False, hatch='xx', width=0.25)
ax.bar(X + 0.33, sen_cases_log.iloc[1,:], color='tab:red', label='Case 2', fill=False, hatch='/', width=0.25)
ax.bar(X + 0.66, sen_cases_log.iloc[2,:], color='tab:blue', label='Case 3', fill=False, hatch='..', width=0.25)
major_ticks = np.arange(0, len(sen_cases_log.columns.values), 1)
ax.set_xticks(major_ticks)
labels = [item.get_text() for item in ax.get_xticklabels()]
labels = sen_cases_log.columns.values
ax.set_xticklabels(labels)
ax.legend(fontsize=14)
ax.set_ylabel('Log sensitivity values', fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=15.5)
ax.tick_params(axis='both', which='minor', labelsize=15)
ax.set_xlabel('Parameters', fontsize=25)
#ax.axhline(y=-11.5,color='k',linestyle='-.')
ax.grid(b='True',which='both')

plt.savefig('log_sen_cases_c.jpg',dpi=300, bbox_inches="tight")

# %% [markdown]
# ##### Which parameters were found most sensitive? Or which group of parameters were found most sensitive? Can you logically explain that? Which parameters were found not sensitive at all? And how do they compare with the literature/material values? Can we classify them based on rank? Based on cases and how the parameters compared with each other?

# %%
sen_cases_log_t = sen_cases_log.transpose()

#sen_cases_log_t

# Saving the table as a png image file (
# Note that it must be recreated in the latex file - https://www.the-cryosphere.net/submission.html#figurestables

dfi.export(sen_cases_log_t,'Tables_data/sen_cases_log_t.png')

# %%
# Note that it must be recreated in the latex file - https://www.the-cryosphere.net/submission.html#figurestables
# Therefore we are creating a new folder where we can store all the data that needs to be plotted as data

sen_cases_log_t.to_csv('Tables_data/sen_cases_log_t.csv',sep=',')

# %% [markdown]
# #### Parameter senstivity ranked values

# %%
# Read ranked sensitivity data 

sen_cases_log_t_ranked_s = pd.read_csv('..\\5_calib\\Final_comp_cases_data\\sen_cases_log_t_ranked_s.csv',sep=',',index_col=0)

sen_cases_log_t_ranked_s
# Out:
#           Case1_rw  Case1_rw_rank   Case2_rw  Case2_rw_rank   Case3_rw  \
# perm_m   12.785093            1.0  15.156661            1.0  14.058614
# perm_p    9.378985            2.0  10.484792            2.0   8.084196
# alpha_m  -8.004672            3.0  -6.998552            3.0  -9.086770
# alpha_p  -8.671411            4.0  -9.913849            4.0  -9.261426
# wr_p    -11.461938            5.0 -11.931702            7.0  -9.711470
# wr_m    -11.540222            6.0        NaN            NaN        NaN
# por_m   -12.155954            7.0 -11.670692            6.0 -10.912206
# por_p   -12.299674            8.0 -11.483687            5.0 -11.029512
# tcd_p   -12.489481            9.0        NaN            NaN        NaN
# tcs_p   -12.517660           10.0        NaN            NaN        NaN
# auf_p   -13.189904           11.0        NaN            NaN        NaN
# n_p     -13.270910           12.0 -13.403977            8.0 -11.469081
# ...

# %% [markdown]
# Comments:
#
# * Ranking the parameters based on sensitivity (Lower rank means greater sensitivity):
#     - High sensitivity: permeability and alpha of both mineral and peat were found be most sensitive
#     - Medium sensitivity: residual saturation of peat and mineral > porosity of mineral and peat > thermal conductivity, thermal specific capacity, auf of peat
#     - Low/negligible sensitivity: n_p > n_m > tcs_m > af_p > tcd_m > af_m > auf_m > den_p > den_m > b_bc

# %%
dfi.export(sen_cases_log_t_ranked_s,'Tables_data/sen_cases_log_t_ranked_s.png')

# %%
# Note that it must be recreated in the latex file - https://www.the-cryosphere.net/submission.html#figurestables

sen_cases_log_t_ranked_s.to_csv('Tables_data/sen_cases_log_t_ranked_s.csv',sep=',')
