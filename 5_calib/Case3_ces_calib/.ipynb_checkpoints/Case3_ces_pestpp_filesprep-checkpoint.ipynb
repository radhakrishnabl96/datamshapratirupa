# %% [markdown]
# **The following file is to calibrate and validate the model with 4 years of data with the results from spinup as the initial condition. Previously in the folder rk_model_final - /home/rk/ats_rk/testing/ats-demos/rk_model/Spinup_final_16032022. The calibration was carried out for only 1 year. All the files will have a similar naming with the ending cv (calibration and validation), su (spinup) and ces(cumalative snow density).**
#
# * The notebook is developed to code the methodology and extract relevant files that are suitable as input to PEST.
# - pestpp/pestpp/benchmarks/mf6_freyberg - This is used as the standard benchmark folder from which the files are referred.
# - Currently, the freyberg6_run_glm.pst which solves the Levenberg - Marquardt algorithm is considered.
#
# Parameters considered: 'alpha_p_gp', 'alpha_m_gp', 'n_p_gp', 'n_m_gp', 'wr_p_gp', 'wr_m_gp', 'tcs_p_gp', 'tcs_m_gp', 'tcd_p_gp', 'tcd_m_gp', 'af_p_gp', 'af_m_gp', 'auf_p_gp', 'auf_m_gp', 'por_p_gp', 'por_m_gp', 'perm_p_gp', 'perm_m_gp', 'den_p_gp', 'den_m_gp'
#
# - We are considering the initial parameters based on the simulation : all_params_afterrw.demo
#
# - The lower and upper bound is fixed to 75 % of the initial value
#
# - Some values that do not accept these changes, have been changed with respect to their initial value
#
# - We are considering to reduce the parameter space so that the pest simulation can run quicker. We will be considering the results from calibration of 1 year - Case5_I_E simulation. Considering the file path - pestpp/pestpp/rk_model_final/Output_comp_analysis_3.ipynb. For the parameters that were not considered in the analysis - the calibrated values from 1 year of calibration is taken. All parameters with log_rel_sen < - 8 is not considered. The results are shown below when the command - rel_cases_log.iloc[1,:][rel_cases_log.iloc[1,:] <-8] was run.
#
#     * n_m         -10.780082
#     * wr_m         -8.237805
#     * tcs_p        -9.283912
#     * tcs_m        -8.707658
#     * tcd_p        -8.552841
#     * tcd_m       -10.539404
#     * af_p        -10.874932
#     * af_m        -10.649015
#     * auf_p        -8.592941
#     * auf_m       -10.588667
#     * den_p       -18.200911
#     * den_m       -17.717395
#     * albedo_bg    -8.457213
#     * e_bg         -8.210573
#     * pen_w        -8.971497
#
#
# - The snow depth dataset is available from 2014 - 2017. The meteorological data is available from the year 2016 - 2020. 2020 - 2021 is not considered for the analysis since it contains missing data for nearly 3 months (2020-02 : 2020-05). **Therefore for Case 3 we can consider the year 2016 as calibration dataset and the year 2017 as validation dataset**. This can ensure that we are working with the right kind of dataset for both calibration and validation.
#
# ### Note that it the daily snow depth dataset without cumulative effect

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# %matplotlib inline
import sys,os
#import colors
import numpy as np
import matplotlib.cm
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import h5py
import pandas as pd
from datetime import datetime
import matplotlib.image as mpimg

# %%
import shutil
import numpy as np
import pandas as pd
#import pyemu
#import flopy
import subprocess

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
directory_name = 'Case3_ces_start_cl.demo' # Main directory name where the data is stored for the initial round of calibration
file_name = 'Case3_ces' # Name of the xml file

# %%
os.getcwd()
# Out:
# '/bigwork/nhgjrabl/Simulations/datamshapratirupa/5_calib/Case3_ces_calib'

# %% [markdown]
# ### 1. Observation data

# %%
df_obs_AWS = pd.read_csv('../../1_data_prep/Final_OutputData_Case3/Calib_outputdata_Case3_2016.csv',sep='\t')
df_obs_AWS.head()

# The observation data was processed previously in /home/rk/ats_rk/testing/ats-demos/rk_model/Data/Data_Yakou/Yakou_met_data_ITP_rk/AWS_final_metdata_4yrs_concise.ipynb
# Out:
#     TIMESTAMP  Soil moisture at - 0.04 m (%)  Soil moisture at - 0.1 m (%)  \
# 0  2016-01-01                       7.897694                      7.523868
# 1  2016-01-02                       7.991826                      7.594250
# 2  2016-01-03                       7.992500                      7.606875
# 3  2016-01-04                       7.960069                      7.581465
# 4  2016-01-05                       7.913792                      7.539000
#
#    Soil moisture at - 0.2 m (%)  Soil moisture at - 0.4 m (%)  \
# 0                      8.694236                      9.016111
# 1                      8.745417                      9.012639
# 2                      8.766806                      9.033472
# 3                      8.749236                      9.025833
# 4                      8.703056                      8.995694
#
#    Soil moisture at - 0.8 m (%)  Soil moisture at - 1.2 m (%)  \
# 0                      5.368792                      4.093549
# 1                      5.350889                      4.060958
# 2                      5.342833                      4.033590
# 3                      5.336757                      4.012583
# 4                      5.324597                      3.993715
#
#    Soil moisture at - 1.6 m (%)  Soil temperature at - 0.00 m (°C)  \
# 0                      6.058042                         -13.103958
# 1                      6.008417                         -12.255417
# 2                      5.962187                         -12.737500
# 3                      5.923819                         -13.006597
# 4                      5.892174                         -13.525278
#
#    Soil temperature at - 0.04 m (°C)  Soil temperature at - 0.1 m (°C)  \
# 0                         -12.507847                        -11.848819
# 1                         -11.861597                        -11.342569
# 2                         -11.824514                        -11.200694
# 3                         -11.997847                        -11.365486
# 4                         -12.371597                        -11.691181
#
#    Soil temperature at - 0.2 m (°C)  Soil temperature at - 0.4 m (°C)  \
# 0                        -11.295486                         -9.824722
# 1                        -10.947708                         -9.781389
# 2                        -10.765278                         -9.618403
# 3                        -10.867778                         -9.648889
# 4                        -11.171181                         -9.829653
#
#    Soil temperature at - 0.8 m (°C)  Soil temperature at - 1.2 m (°C)  \
# 0                         -7.814958                         -4.874889
# 1                         -7.936854                         -5.063889
# 2                         -7.946111                         -5.228028
# 3                         -7.977951                         -5.358771
# 4                         -8.078194                         -5.476889
#
#    Soil temperature at - 1.6 m (°C)
# 0                         -3.447965
# 1                         -3.639549
# 2                         -3.817500
# 3                         -3.977958
# 4                         -4.119438

# %%
len(df_obs_AWS)
# Out:
# 366

# %%
# Calculating the temperature in Kelvin

depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

time_values = len(df_obs_AWS) # Number of time values

times = np.arange(1, time_values+1, 1)

# Adding column information:


x = 0
for i, depth in enumerate(depths):
        df_obs_AWS[f'Soil temperature at - {depth} m (K)'] = df_obs_AWS[f'Soil temperature at - {depth} m (°C)'] + 273.15

df_obs_AWS['Soil temperature at - 0.04 m (K)'].head()
# Out:
# 0    260.642153
# 1    261.288403
# 2    261.325486
# 3    261.152153
# 4    260.778403
# Name: Soil temperature at - 0.04 m (K), dtype: float64

# %%
# Extracting an example 
obs_data_example = pd.read_csv('../Freyberg_example/freyberg6_run_glm.obs_data.csv') 
obs_data_example.head()
# Out:
#             obsnme   obsval    weight obgnme
# 0  gage_1_20151231   951.71  0.000000   gage
# 1  gage_1_20160131  1530.10  0.004357   gage
# 2  gage_1_20160229  1855.30  0.003593   gage
# 3  gage_1_20160331  1907.10  0.003496   gage
# 4  gage_1_20160430  1747.70  0.003815   gage

# %%
obs_weight = 2 * 7 * 366
obs_weight
# Out:
# 5124

# %% [markdown]
# The following details need to be defined:
#
# Note: Here we need to add the values from the excel that we read previously.
#
# - OBSNME: stemp_{depth}_{1-366} & smois_{depth}_{1-366}: Observation names - We have temperature and moisture values at 7 depths.
# - OBSVAL: The corresponding values need to be added in pandas from the dataframe - data_AWS_syn_2016
# - WEIGHT (Initial): Assigning equal weights to all variables. 1/5124 = 1.9516e-04; 2 {soil_temp, soil_mois} * 7 {7 sensors} * 366 {1-366}  = 5124
# - obgnme: 'temp', 'mois'

# %%
# Initial values 
time_values = 366 # Number of time values
# Total number of values 1/15344 = 6.517e-05; 2 {soil_temp, soil_mois} * 7 {7 sensors} * 1096 {1-365}  = 15344
total_values = 2 * 7 * 366 
ini_wt = 1/total_values # Initial weight
ini_wt
# Out:
# 0.000195160031225605

# %%
# Creating a new dataframes with columns = obs_data_example.index and rows = 0 - 15344
# There are 1096 values for one sensor in each year, hence we move from 0 - 1095 & then it repeats again for the next sensor.

obs_data = pd.DataFrame(data=None,columns=obs_data_example.columns,index=np.arange(1,total_values+1,1))


depths = [0.04, 0.1, 0.2, 0.4, 0.8, 1.2, 1.6]

times = np.arange(1, time_values+1, 1)

# Adding column information:


x = 0
for i, depth in enumerate(depths):
    for j, time in enumerate(times):
        # Column name = obsnme
        obs_data.iloc[x,0] = f'stemp_{depth}_{j}'
        # Column name = obsval
        obs_data.iloc[x,1] = df_obs_AWS[f'Soil temperature at - {depth} m (K)'][j]
        # Column name = weights : Assigning equal weight to all variables
        obs_data.iloc[x,2] = 1/total_values
        # Column name = obgnme : Assigning observation group name
        obs_data.iloc[x,3] = 'temp'
        x = x + 1

for i, depth in enumerate(depths):
    for j, time in enumerate(times):
        obs_data.iloc[x,0] = f'smois_{depth}_{j}'
        # Column name = obsval
        obs_data.iloc[x,1] = df_obs_AWS[f'Soil moisture at - {depth} m (%)'][j]
        # Column name = weights : Assigning equal weight to all variables
        obs_data.iloc[x,2] = 1/total_values
        # Column name = obgnme : Assigning observation group name
        obs_data.iloc[x,3] = 'mois'
        x = x + 1

        
obs_data.head()
# Out:
#          obsnme      obsval    weight obgnme
# 1  stemp_0.04_0  260.642153  0.000195   temp
# 2  stemp_0.04_1  261.288403  0.000195   temp
# 3  stemp_0.04_2  261.325486  0.000195   temp
# 4  stemp_0.04_3  261.152153  0.000195   temp
# 5  stemp_0.04_4  260.778403  0.000195   temp

# %%
df_obs_AWS['Soil temperature at - 0.2 m (K)'][200:205]
# Out:
# 200    279.461694
# 201    280.641611
# 202    280.277917
# 203    279.958944
# 204    280.124236
# Name: Soil temperature at - 0.2 m (K), dtype: float64

# %%
# Check the observation values
obs_data.iloc[932:936]
# Out:
#             obsnme      obsval    weight obgnme
# 933  stemp_0.2_200  279.461694  0.000195   temp
# 934  stemp_0.2_201  280.641611  0.000195   temp
# 935  stemp_0.2_202  280.277917  0.000195   temp
# 936  stemp_0.2_203  279.958944  0.000195   temp

# %%
directory_name
# Out:
# 'Case3_start.demo'

# %%
file_name
# Out:
# 'Case3'

# %%
# Exporting the observation data csv file
obs_data.to_csv(f'{directory_name}/{file_name}_obs_data.csv', index=False)

# %% [markdown]
# ### 2. Parameter groups external
# - Extracting the data from the example

# %%
pargrp_data_example = pd.read_csv('../Freyberg_example/freyberg6_run_glm.pargrp_data.csv') 
pargrp_data_example.head()
# Out:
#     pargpnme    inctyp  derinc  derinclb  forcen  derincmul    dermthd  \
# 0   sto_ss_0  relative    0.01       0.0  switch        2.0  parabolic
# 1  npf_k33_1  relative    0.01       0.0  switch        2.0  parabolic
# 2    npf_k_1  relative    0.01       0.0  switch        2.0  parabolic
# 3   sto_ss_1  relative    0.01       0.0  switch        2.0  parabolic
# 4    npf_k_0  relative    0.01       0.0  switch        2.0  parabolic
#
#    splitthresh  splitreldiff splitaction
# 0      0.00001           0.5     smaller
# 1      0.00001           0.5     smaller
# 2      0.00001           0.5     smaller
# 3      0.00001           0.5     smaller
# 4      0.00001           0.5     smaller

# %% [markdown]
# #### Defining the variables in Parameter Group variables:
# - PARGPNME : Individual groups assigned for all parameters! - Assigned a total of 20 parameters (10 for each material)
# - INCTYP : 'relative' - The increment used for forward-difference calculation of derivatives with respect to any parameter belonging to the group is calculated as the fraction of the current value of that parameter; that fraction is provided as the real variable DERINC. Ex: If current value of parameter = 10 & DERINC =  0.01. Then the next parameter value = 0.01 * 10 = 0.1.
# - DERINC : '0.01' - The fraction of increment of the current value of parameter. [Consider the range of variation of the parameters, upper and lower bounds]
# - DERINCLB : '0.0'
# - FORCEN : 'switch'. In the first iteration, forward difference method is employed. From the second iteration, it switches to central difference method for the remainder of the inversion process on the iteration after which the relative objective function reduction between successive iterations is less than PHIREDSWH. Note we need to define PHIREDSWH (Where is it defined in this format?)
# - DERINCMUL : '1.0' - If three-point derivatives calculation is employed, the value of DERINC is multiplied by DERINCMUL.
# - DERMTHD : 'parabolic' - This is preferred as it provides greater accuracy.
# - [SPLITTHRESH] [SPLITRELDIFF] [SPLITACTION] - For the first analysis, we ignore the three variables.

# %%
pargrp = pargrp_data_example.copy()
# Dropping all rows to replace with the two newly defined rows
pargrp.drop(pargrp.index, inplace=True)
# Dropping the columns - splitthresh, splitreldiff, splitaction
pargrp.drop(columns=['splitthresh', 'splitreldiff', 'splitaction'], inplace=True)

group_names = ['alpha_p_gp', 'alpha_m_gp', 'n_p_gp', 'wr_p_gp', 'por_p_gp', 'por_m_gp', 'perm_p_gp', 'perm_m_gp', 'pen_s_gp','z_bg_gp','z_s_gp','b_bc_gp']

for i, gp_nm in enumerate(group_names):
    pargrp.loc[i] = [gp_nm, 'relative',0.1,0.0,'switch',1.0,'parabolic']
    #print(i, gp_nm)
    
pargrp
# Out:
#       pargpnme    inctyp  derinc  derinclb  forcen  derincmul    dermthd
# 0   alpha_p_gp  relative     0.1       0.0  switch        1.0  parabolic
# 1   alpha_m_gp  relative     0.1       0.0  switch        1.0  parabolic
# 2       n_p_gp  relative     0.1       0.0  switch        1.0  parabolic
# 3      wr_p_gp  relative     0.1       0.0  switch        1.0  parabolic
# 4     por_p_gp  relative     0.1       0.0  switch        1.0  parabolic
# 5     por_m_gp  relative     0.1       0.0  switch        1.0  parabolic
# 6    perm_p_gp  relative     0.1       0.0  switch        1.0  parabolic
# 7    perm_m_gp  relative     0.1       0.0  switch        1.0  parabolic
# 8     pen_s_gp  relative     0.1       0.0  switch        1.0  parabolic
# 9      z_bg_gp  relative     0.1       0.0  switch        1.0  parabolic
# 10      z_s_gp  relative     0.1       0.0  switch        1.0  parabolic
# 11     b_bc_gp  relative     0.1       0.0  switch        1.0  parabolic

# %%
directory_name
# Out:
# 'Case3_start.demo'

# %%
### The derinc value for bottom_bc needs to be reduced by a factor of 10 - i.e. derinc = 0.001
# 268.45 * 0.1 = 26.845 which does not lie in the parameter range (263.15 - 274.15)

pargrp.iloc[11,2] = 0.01

# %%
file_name
# Out:
# 'Case3'

# %%
# Exporting the parameter group csv file
pargrp.to_csv(f'{directory_name}/{file_name}_pargrp_data.csv', index=False)

# %% [markdown]
# ### 3. Parameter names external
# There are 12 parameters that we are considering for this analysis

# %%
par_data_example = pd.read_csv('../Freyberg_example/freyberg6_run_glm.par_data.csv') 
par_data_example.head()
# Out:
#               parnme partrans parchglim  parval1  parlbnd  parubnd      pargp  \
# 0  npf_k33_0_000_000      log    factor      0.3     0.03      3.0  npf_k33_0
# 1  npf_k33_0_000_001     tied    factor      0.3     0.03      3.0  npf_k33_0
# 2  npf_k33_0_000_002     tied    factor      0.3     0.03      3.0  npf_k33_0
# 3  npf_k33_0_000_003     tied    factor      0.3     0.03      3.0  npf_k33_0
# 4  npf_k33_0_000_004     tied    factor      0.3     0.03      3.0  npf_k33_0
#
#    scale  offset  dercom            partied
# 0    1.0     0.0       1                NaN
# 1    1.0     0.0       1  npf_k33_0_000_000
# 2    1.0     0.0       1  npf_k33_0_000_000
# 3    1.0     0.0       1  npf_k33_0_000_000
# 4    1.0     0.0       1  npf_k33_0_000_000

# %% [markdown]
# The following details need to be defined:
# - PARNME: 'n_m', 'tcs_m', 'af_m', 'af_p', .... - It is the parameter name
# - PARTRANS: 'none' {'log' - Can we considered later if the inversion process does not occur. Log-transformations helps in ensuring that the parameter changes and model output changes are more linear.}
# - PARCHGLIM: 'factor' - Alteration to a parameter's value is factor-limited. { PARCHGLIM must be provided with a value of “relative” or “factor”. The former designates that alterations to a parameter’s value are factor-limited whereas the latter designates that alterations to its value are relative-limited. }
# - PARVALI: 1.2, 1, 0.05, 0.005 - These are the starting values for the parameters
# - PARLBND: 1.05, 0.8, 0.02, 0.002 - Lower bounds for the parameters.
# - PARUBND: 3, 2.5, 0.1, 0.01 - Upper bounds for the parameters.
# - PARGRP: 'hydraulic','thermal','hydraulic', 'hydraulic' - It is the parameter group names associated with the parameters.
# - SCALE: 1.0, 1.0, 1.0, 1.0 - No scale or offset is provided
# - OFFSET: 0.0, 0.0, 0.0, 0.0 - No scale or offset is provided
# - DERCOM: 1, 1, 1, 1 - Only model command exists. Hence we give 1 which represents 'ats'
# - Partied: This column will be dropped since we have no tied elements

# %%
directory_name_params = '../Case5_I_E_suitable_params.csv'

best_params = pd.read_csv(f'{directory_name_params}')


best_params_concise = best_params.drop(best_params.index[[3,5,6,7,8,9,10,11,12,13,18,19,20,21,22]])

best_params_concise
#best_params.drop(ndex=['n_m','wr_m','tcs_p','tcs_m','tcd_p','tcd_m','af_p','af_m','auf_p','auf_m','den_p','den_m'],inplace=True)
# Out:
#      parnme partrans parchglim       parval1       parlbnd       parubnd  \
# 0   alpha_p     none    factor  1.000000e-02  2.500000e-03  1.250000e-02
# 1   alpha_m     none    factor  1.824914e-03  4.562286e-04  3.193600e-03
# 2       n_p     none    factor  1.500000e+00  1.025000e+00  2.050000e+00
# 4      wr_p     none    factor  1.000000e-01  2.400000e-02  2.000000e-01
# 14    por_p     none    factor  6.373900e-01  1.590000e-01  8.500000e-01
# 15    por_m     none    factor  4.810308e-01  1.202577e-01  8.418038e-01
# 16   perm_p     none    factor  5.346622e-11  1.336656e-11  9.356589e-11
# 17   perm_m     none    factor  1.000000e-13  2.500000e-14  1.750000e-13
# 23    pen_s     none    factor  2.000000e-02  5.000000e-03  3.500000e-02
# 24     z_bg     none    factor  4.000000e-02  1.000000e-02  7.000000e-02
# 25      z_s     none    factor  5.000000e-03  1.250000e-03  8.750000e-03
#
#          pargp  scale  offset  dercom
# 0   alpha_p_gp    1.0     0.0       1
# 1   alpha_m_gp    1.0     0.0       1
# 2       n_p_gp    1.0     0.0       1
# 4      wr_p_gp    1.0     0.0       1
# 14    por_p_gp    1.0     0.0       1
# 15    por_m_gp    1.0     0.0       1
# 16   perm_p_gp    1.0     0.0       1
# 17   perm_m_gp    1.0     0.0       1
# 23    pen_s_gp    1.0     0.0       1
# 24     z_bg_gp    1.0     0.0       1
# 25      z_s_gp    1.0     0.0       1

# %%
# Getting the best parameter dataset from the simulation - all_params_afterrw.demo
#directory_name_params = 'all_params_afterrw.demo'
#best_params_afterrw = pd.read_csv(f'{directory_name_params}/rk_model_glm_cf_v1_allparams_rw.par',delimiter='\s+',skiprows=1, header=None)
#best_params_afterrw.drop(columns=[2,3],inplace=True)
#best_params_afterrw.columns = ['parameter','PARVAL1']
#best_params_afterrw.head()



#length_index = len(best_params_afterrw.index)


#best_params_afterrw.index = best_params_afterrw['parameter']
#best_params_afterrw.drop(columns='parameter',inplace=True)

# Dropping all parameters that are not of interest

#best_params_afterrw.drop(index=['n_m','wr_m','tcs_p','tcs_m','tcd_p','tcd_m','af_p','af_m','auf_p','auf_m','den_p','den_m'],inplace=True)

# %%
# Changing the initial value of n_p, n_m and den_m
#best_params_afterrw.loc['n_p'] = 2.05 # Since value below 1.05 is not allowed
#best_params_afterrw.loc['n_m'] = 2.05 # Since value below 1.05 is not allowed
#best_params_afterrw.loc['den_m'] = 1900 # Since value above 2700 represents a soil mineral layer
#best_params_afterrw.loc['b_bc'] = 268.45 # Average temperature at Yakou catchment - -4.7 °C

#best_params_afterrw.loc['perm_p'] = 5.346622127220000e-11

# Changing to float type 
#best_params_afterrw = best_params_afterrw.astype('float64')

# Adding the lower and upper bound - 75% for all params except n_p, n_m and den_m which is given 50 %
#best_params_afterrw['PARLBND'] = best_params_afterrw['PARVAL1']*0.25
#best_params_afterrw['PARUBND'] = best_params_afterrw['PARVAL1']*1.75


#best_params_afterrw.loc['n_p']['PARLBND'] = best_params_afterrw.loc['n_p']['PARVAL1']*0.5
#best_params_afterrw.loc['n_p']['PARUBND'] = best_params_afterrw.loc['n_p']['PARVAL1']*1.5

#best_params_afterrw.loc['n_m']['PARLBND'] = best_params_afterrw.loc['n_m']['PARVAL1']*0.5
#best_params_afterrw.loc['n_m']['PARUBND'] = best_params_afterrw.loc['n_m']['PARVAL1']*1.5

#best_params_afterrw.loc['den_m']['PARLBND'] = best_params_afterrw.loc['den_m']['PARVAL1']*0.5
#best_params_afterrw.loc['den_m']['PARUBND'] = best_params_afterrw.loc['den_m']['PARVAL1']*1.5

# The bottom B.C - upper bound is given 1°C (274.15) and the lower bound is given -10°C (263.15)
#best_params_afterrw.loc['b_bc']['PARLBND'] = 263.15 
#best_params_afterrw.loc['b_bc']['PARUBND'] = 274.15

#best_params_afterrw

# %%
par_data = best_params_concise.copy()

# %%
#par_data = par_data_example.copy()
#par_data.drop(par_data.index, inplace=True)
# Dropping the columns - splitthresh, splitreldiff, splitaction
#par_data.drop(columns=['partied'], inplace=True)

#param_names = ['alpha_p', 'alpha_m', 'n_p', 'n_m', 'wr_p', 'wr_m', 'tcs_p', 'tcs_m', 'tcd_p', 'tcd_m', 'af_p', 'af_m', 'auf_p', 'por_p', 'por_m', 'perm_p', 'perm_m', 'den_p', 'den_m', 'lh_w','lh_i','hc_l','hc_r']

#for i, values in enumerate(best_params_afterrw.index):
    #par_data.loc[i] = [best_params_afterrw.index[i], 'none','factor', best_params_afterrw['PARVAL1'].values[i], best_params_afterrw['PARLBND'].values[i], best_params_afterrw['PARUBND'].values[i], pargrp['pargpnme'].values[i], 1.0, 0.0, 1] 

#par_data
# Adding row information for surface parameters:

#par_data.loc[par_data.index.max()+1] = ['albedo_bg','none','factor', 0.55, 0.55*0.25, 0.55*1.75, 'albedo_bg_gp', 1.0, 0.0, 1]
#par_data.loc[par_data.index.max()+1] = ['e_bg','none','factor', 0.55, 0.55*0.25, 0.55*1.75, 'e_bg_gp', 1.0, 0.0, 1]
#par_data.loc[par_data.index.max()+1] = ['pen_w','none','factor', 0.01, 0.01*0.25, 0.01*1.75, 'pen_w_gp', 1.0, 0.0, 1]
#par_data.loc[par_data.index.max()+1] = ['pen_s','none','factor', 0.02, 0.02*0.25, 0.02*1.75, 'pen_s_gp', 1.0, 0.0, 1]
#par_data.loc[par_data.index.max()+1] = ['z_bg','none','factor', 0.04, 0.04*0.25, 0.04*1.75, 'z_bg_gp', 1.0, 0.0, 1]
#par_data.loc[par_data.index.max()+1] = ['z_s','none','factor', 0.005, 0.005*0.25, 0.005*1.75, 'albedo_bg_gp', 1.0, 0.0, 1]
#par_data.loc[1] = ['alpha_m','none','factor', 0.005, 0.001, 0.01, 'alpha_m_gp', 1.0, 0.0, 1]

# The bottom B.C - upper bound is given 1°C (274.15) and the lower bound is given -10°C (263.15)
par_data.loc[par_data.index.max()+1] = ['b_bc','none','factor', 268.45, 263.15, 274.15, 'b_bc_gp', 1.0, 0.0, 1]


par_data
# Out:
#      parnme partrans parchglim       parval1       parlbnd       parubnd  \
# 0   alpha_p     none    factor  1.000000e-02  2.500000e-03  1.250000e-02
# 1   alpha_m     none    factor  1.824914e-03  4.562286e-04  3.193600e-03
# 2       n_p     none    factor  1.500000e+00  1.025000e+00  2.050000e+00
# 4      wr_p     none    factor  1.000000e-01  2.400000e-02  2.000000e-01
# 14    por_p     none    factor  6.373900e-01  1.590000e-01  8.500000e-01
# 15    por_m     none    factor  4.810308e-01  1.202577e-01  8.418038e-01
# 16   perm_p     none    factor  5.346622e-11  1.336656e-11  9.356589e-11
# 17   perm_m     none    factor  1.000000e-13  2.500000e-14  1.750000e-13
# 23    pen_s     none    factor  2.000000e-02  5.000000e-03  3.500000e-02
# 24     z_bg     none    factor  4.000000e-02  1.000000e-02  7.000000e-02
# 25      z_s     none    factor  5.000000e-03  1.250000e-03  8.750000e-03
# 26     b_bc     none    factor  2.684500e+02  2.631500e+02  2.741500e+02
#
#          pargp  scale  offset  dercom
# 0   alpha_p_gp    1.0     0.0       1
# 1   alpha_m_gp    1.0     0.0       1
# 2       n_p_gp    1.0     0.0       1
# 4      wr_p_gp    1.0     0.0       1
# 14    por_p_gp    1.0     0.0       1
# 15    por_m_gp    1.0     0.0       1
# 16   perm_p_gp    1.0     0.0       1
# 17   perm_m_gp    1.0     0.0       1
# 23    pen_s_gp    1.0     0.0       1
# 24     z_bg_gp    1.0     0.0       1
# 25      z_s_gp    1.0     0.0       1
# 26     b_bc_gp    1.0     0.0       1

# %%
pargrp
# Out:
#       pargpnme    inctyp  derinc  derinclb  forcen  derincmul    dermthd
# 0   alpha_p_gp  relative    0.10       0.0  switch        1.0  parabolic
# 1   alpha_m_gp  relative    0.10       0.0  switch        1.0  parabolic
# 2       n_p_gp  relative    0.10       0.0  switch        1.0  parabolic
# 3      wr_p_gp  relative    0.10       0.0  switch        1.0  parabolic
# 4     por_p_gp  relative    0.10       0.0  switch        1.0  parabolic
# 5     por_m_gp  relative    0.10       0.0  switch        1.0  parabolic
# 6    perm_p_gp  relative    0.10       0.0  switch        1.0  parabolic
# 7    perm_m_gp  relative    0.10       0.0  switch        1.0  parabolic
# 8     pen_s_gp  relative    0.10       0.0  switch        1.0  parabolic
# 9      z_bg_gp  relative    0.10       0.0  switch        1.0  parabolic
# 10      z_s_gp  relative    0.10       0.0  switch        1.0  parabolic
# 11     b_bc_gp  relative    0.01       0.0  switch        1.0  parabolic

# %%
# Exporting the parameter group csv file
par_data.to_csv(f'{directory_name}/{file_name}_par_data.csv', index=False)

# %%
os.getcwd()
# Out:
# '/home/rk/pestpp/pestpp/rk_model_final_4yrs_su'

# %% [markdown]
# ### Template files

# %% [markdown]
# - It could be created by manually editing the files.

# %% [markdown]
# ### Instruction files

# %%
#os.chdir('..')

# %%
#os.chdir('Case5_su_cv_start_cl.demo')

# %%
# Reading the simulated data - from the xml file generated
sim_data = pd.read_csv(f'{directory_name}/observations.dat',sep=' ',skiprows=88) 

sim_data.head()
# Out:
#    time [s]  point -0.04 temperature [K]  point -0.1 temperature [K]  \
# 0       0.0                   269.134510                  269.824655
# 1   86400.0                   269.421964                  269.895492
# 2  172800.0                   269.584311                  269.980281
# 3  259200.0                   269.736180                  270.067058
# 4  345600.0                   269.826550                  270.123556
#
#    point -0.2 temperature [K]  point -0.4 temperature [K]  \
# 0                  270.454577                  271.081625
# 1                  270.379834                  270.908316
# 2                  270.383729                  270.832489
# 3                  270.407321                  270.792139
# 4                  270.424823                  270.765161
#
#    point -0.8 temperature [K]  point -1.2 temperature [K]  \
# 0                  272.128637                  272.510957
# 1                  271.909510                  272.404970
# 2                  271.744671                  272.288038
# 3                  271.614978                  272.173011
# 4                  271.512048                  272.065549
#
#    point -1.6 temperature [K]  point -0.04 saturation liquid  \
# 0                  272.424620                       0.162131
# 1                  272.391156                       0.162352
# 2                  272.341358                       0.162488
# 3                  272.282015                       0.162624
# 4                  272.216873                       0.162709
#
#    point -0.1 saturation liquid  point -0.2 saturation liquid  \
# 0                      0.162707                      0.163412
# 1                      0.162776                      0.163316
# 2                      0.162861                      0.163321
# 3                      0.162953                      0.163351
# 4                      0.163014                      0.163373
#
#    point -0.4 saturation liquid  point -0.8 saturation liquid  \
# 0                      0.164430                      0.167828
# 1                      0.164105                      0.166769
# 2                      0.163974                      0.166138
# 3                      0.163906                      0.165714
# 4                      0.163861                      0.165414
#
#    point -1.2 saturation liquid  point -1.6 saturation liquid
# 0                      0.170772                      0.169899
# 1                      0.169722                      0.169601
# 2                      0.168794                      0.169192
# 3                      0.168047                      0.168751
# 4                      0.167459                      0.168316

# %%
len(sim_data)
# Out:
# 367

# %%
# Excluding the first value (since it is the initial condition)
#sim_data = sim_data.iloc[1:,:]

# %%
# Creating an instruction file suitable for the analysis
ins_data = pd.DataFrame(columns=sim_data.columns, index=sim_data.index)

# Adding the simulated variables [Temperature & Moisture] in the instruction file

# Temperature
for i, depth in enumerate(depths):
    for j, time in enumerate(times):
        # Column name = obsnme
        # (i + 1) - Signifies the start from the 2nd column
        ins_data.iloc[j+1, i+1] = f' !stemp_{depth}_{j}! ' 

# Moisture
for i, depth in enumerate(depths):
    for j, time in enumerate(times):
        # Column name = obsnme
        # (i + 1) - Signifies the start from the 2nd column
        ins_data.iloc[j+1, i+8] = f' !smois_{depth}_{j}! ' 

ins_data.head()
# Out:
#   time [s] point -0.04 temperature [K] point -0.1 temperature [K]  \
# 0      NaN                         NaN                        NaN
# 1      NaN             !stemp_0.04_0!              !stemp_0.1_0!
# 2      NaN             !stemp_0.04_1!              !stemp_0.1_1!
# 3      NaN             !stemp_0.04_2!              !stemp_0.1_2!
# 4      NaN             !stemp_0.04_3!              !stemp_0.1_3!
#
#   point -0.2 temperature [K] point -0.4 temperature [K]  \
# 0                        NaN                        NaN
# 1             !stemp_0.2_0!              !stemp_0.4_0!
# 2             !stemp_0.2_1!              !stemp_0.4_1!
# 3             !stemp_0.2_2!              !stemp_0.4_2!
# 4             !stemp_0.2_3!              !stemp_0.4_3!
#
#   point -0.8 temperature [K] point -1.2 temperature [K]  \
# 0                        NaN                        NaN
# 1             !stemp_0.8_0!              !stemp_1.2_0!
# 2             !stemp_0.8_1!              !stemp_1.2_1!
# 3             !stemp_0.8_2!              !stemp_1.2_2!
# 4             !stemp_0.8_3!              !stemp_1.2_3!
#
#   point -1.6 temperature [K] point -0.04 saturation liquid  \
# 0                        NaN                           NaN
# 1             !stemp_1.6_0!                !smois_0.04_0!
# 2             !stemp_1.6_1!                !smois_0.04_1!
# 3             !stemp_1.6_2!                !smois_0.04_2!
# 4             !stemp_1.6_3!                !smois_0.04_3!
#
#   point -0.1 saturation liquid point -0.2 saturation liquid  \
# 0                          NaN                          NaN
# 1               !smois_0.1_0!                !smois_0.2_0!
# 2               !smois_0.1_1!                !smois_0.2_1!
# 3               !smois_0.1_2!                !smois_0.2_2!
# 4               !smois_0.1_3!                !smois_0.2_3!
#
#   point -0.4 saturation liquid point -0.8 saturation liquid  \
# 0                          NaN                          NaN
# 1               !smois_0.4_0!                !smois_0.8_0!
# 2               !smois_0.4_1!                !smois_0.8_1!
# 3               !smois_0.4_2!                !smois_0.8_2!
# 4               !smois_0.4_3!                !smois_0.8_3!
#
#   point -1.2 saturation liquid point -1.6 saturation liquid
# 0                          NaN                          NaN
# 1               !smois_1.2_0!                !smois_1.6_0!
# 2               !smois_1.2_1!                !smois_1.6_1!
# 3               !smois_1.2_2!                !smois_1.6_2!
# 4               !smois_1.2_3!                !smois_1.6_3!

# %%
# Removing the last character from the last column '~' to mimic the file sfr.csv.in
ins_data["point -1.6 saturation liquid"] = ins_data["point -1.6 saturation liquid"].str[:-1]
ins_data["point -1.6 saturation liquid"].tail()
# Out:
# 362     !smois_1.6_361!
# 363     !smois_1.6_362!
# 364     !smois_1.6_363!
# 365     !smois_1.6_364!
# 366     !smois_1.6_365!
# Name: point -1.6 saturation liquid, dtype: object

# %%
# Replacing the time vaiable with ~dum
ins_data['time [s]'] = f' !dum! '

# Dropping unnecessary row and column
#ins_data.drop(['time [s]'], axis=1, inplace=True)
ins_data.drop([0], axis=0, inplace=True)
ins_data.head()
# Out:
#   time [s] point -0.04 temperature [K] point -0.1 temperature [K]  \
# 1   !dum!              !stemp_0.04_0!              !stemp_0.1_0!
# 2   !dum!              !stemp_0.04_1!              !stemp_0.1_1!
# 3   !dum!              !stemp_0.04_2!              !stemp_0.1_2!
# 4   !dum!              !stemp_0.04_3!              !stemp_0.1_3!
# 5   !dum!              !stemp_0.04_4!              !stemp_0.1_4!
#
#   point -0.2 temperature [K] point -0.4 temperature [K]  \
# 1             !stemp_0.2_0!              !stemp_0.4_0!
# 2             !stemp_0.2_1!              !stemp_0.4_1!
# 3             !stemp_0.2_2!              !stemp_0.4_2!
# 4             !stemp_0.2_3!              !stemp_0.4_3!
# 5             !stemp_0.2_4!              !stemp_0.4_4!
#
#   point -0.8 temperature [K] point -1.2 temperature [K]  \
# 1             !stemp_0.8_0!              !stemp_1.2_0!
# 2             !stemp_0.8_1!              !stemp_1.2_1!
# 3             !stemp_0.8_2!              !stemp_1.2_2!
# 4             !stemp_0.8_3!              !stemp_1.2_3!
# 5             !stemp_0.8_4!              !stemp_1.2_4!
#
#   point -1.6 temperature [K] point -0.04 saturation liquid  \
# 1             !stemp_1.6_0!                !smois_0.04_0!
# 2             !stemp_1.6_1!                !smois_0.04_1!
# 3             !stemp_1.6_2!                !smois_0.04_2!
# 4             !stemp_1.6_3!                !smois_0.04_3!
# 5             !stemp_1.6_4!                !smois_0.04_4!
#
#   point -0.1 saturation liquid point -0.2 saturation liquid  \
# 1               !smois_0.1_0!                !smois_0.2_0!
# 2               !smois_0.1_1!                !smois_0.2_1!
# 3               !smois_0.1_2!                !smois_0.2_2!
# 4               !smois_0.1_3!                !smois_0.2_3!
# 5               !smois_0.1_4!                !smois_0.2_4!
#
#   point -0.4 saturation liquid point -0.8 saturation liquid  \
# 1               !smois_0.4_0!                !smois_0.8_0!
# 2               !smois_0.4_1!                !smois_0.8_1!
# 3               !smois_0.4_2!                !smois_0.8_2!
# 4               !smois_0.4_3!                !smois_0.8_3!
# 5               !smois_0.4_4!                !smois_0.8_4!
#
#   point -1.2 saturation liquid point -1.6 saturation liquid
# 1               !smois_1.2_0!                 !smois_1.6_0!
# 2               !smois_1.2_1!                 !smois_1.6_1!
# 3               !smois_1.2_2!                 !smois_1.6_2!
# 4               !smois_1.2_3!                 !smois_1.6_3!
# 5               !smois_1.2_4!                 !smois_1.6_4!

# %%
#ins_data['l1'] = 'l1 ~'
# Adding an extra column to mimic sfr.csv.ins
ins_data.insert(0, 'l1', 'l1 ')

# %%
ins_data.head()
# Out:
#     l1 time [s] point -0.04 temperature [K] point -0.1 temperature [K]  \
# 1  l1    !dum!              !stemp_0.04_0!              !stemp_0.1_0!
# 2  l1    !dum!              !stemp_0.04_1!              !stemp_0.1_1!
# 3  l1    !dum!              !stemp_0.04_2!              !stemp_0.1_2!
# 4  l1    !dum!              !stemp_0.04_3!              !stemp_0.1_3!
# 5  l1    !dum!              !stemp_0.04_4!              !stemp_0.1_4!
#
#   point -0.2 temperature [K] point -0.4 temperature [K]  \
# 1             !stemp_0.2_0!              !stemp_0.4_0!
# 2             !stemp_0.2_1!              !stemp_0.4_1!
# 3             !stemp_0.2_2!              !stemp_0.4_2!
# 4             !stemp_0.2_3!              !stemp_0.4_3!
# 5             !stemp_0.2_4!              !stemp_0.4_4!
#
#   point -0.8 temperature [K] point -1.2 temperature [K]  \
# 1             !stemp_0.8_0!              !stemp_1.2_0!
# 2             !stemp_0.8_1!              !stemp_1.2_1!
# 3             !stemp_0.8_2!              !stemp_1.2_2!
# 4             !stemp_0.8_3!              !stemp_1.2_3!
# 5             !stemp_0.8_4!              !stemp_1.2_4!
#
#   point -1.6 temperature [K] point -0.04 saturation liquid  \
# 1             !stemp_1.6_0!                !smois_0.04_0!
# 2             !stemp_1.6_1!                !smois_0.04_1!
# 3             !stemp_1.6_2!                !smois_0.04_2!
# 4             !stemp_1.6_3!                !smois_0.04_3!
# 5             !stemp_1.6_4!                !smois_0.04_4!
#
#   point -0.1 saturation liquid point -0.2 saturation liquid  \
# 1               !smois_0.1_0!                !smois_0.2_0!
# 2               !smois_0.1_1!                !smois_0.2_1!
# 3               !smois_0.1_2!                !smois_0.2_2!
# 4               !smois_0.1_3!                !smois_0.2_3!
# 5               !smois_0.1_4!                !smois_0.2_4!
#
#   point -0.4 saturation liquid point -0.8 saturation liquid  \
# 1               !smois_0.4_0!                !smois_0.8_0!
# 2               !smois_0.4_1!                !smois_0.8_1!
# 3               !smois_0.4_2!                !smois_0.8_2!
# 4               !smois_0.4_3!                !smois_0.8_3!
# 5               !smois_0.4_4!                !smois_0.8_4!
#
#   point -1.2 saturation liquid point -1.6 saturation liquid
# 1               !smois_1.2_0!                 !smois_1.6_0!
# 2               !smois_1.2_1!                 !smois_1.6_1!
# 3               !smois_1.2_2!                 !smois_1.6_2!
# 4               !smois_1.2_3!                 !smois_1.6_3!
# 5               !smois_1.2_4!                 !smois_1.6_4!

# %%
# Exporting the instruction file
ins_data.to_csv(f'{directory_name}/{file_name}_obs_data.dat.ins', header=False, index=False,sep=' ')

# %% [markdown]
# ##### Dont forget to remove Quotes & add 'pif ~' string manually ;) (Dont know why the quotes are appearing as it did not in previous formats!
# ##### Also check if the spacing, indentation and rest of the content is correct by checking with the another instruction file (preferably by vs code?)

# %% [markdown]
# ### Running pest in python:
# 1. Checks to be done
#
#     a. TEMPCHEK - To check the template file
#
#     b. INSCHEK - To check the instruction file
#
#     c. Converting the file to version 1
#
#     d. PESTCHEK - To check the pest control file
#
# 2. Running PEST (Not PEST++) with NOPTMAX = -1 (Wait until the results are displayed)
#
# 3. Running PWTADJ1 - pwtadj1 case1_v1.pst case2_v1_new.pst contribution
#
# 4. Running PEST++ for the redistributed weights

# %%
file_name
# Out:
# 'Case3_ces'

# %%
directory_name
# Out:
# 'Case3_ces_start_cl.demo'

# %%
os.getcwd()
# Out:
# '/bigwork/nhgjrabl/Simulations/datamshapratirupa/5_calib/Case3_ces_calib'

# %%
# Change directory to required directory with simulation input files
os.chdir(f'{directory_name}')

# %%
os.getcwd()
# Out:
# '/bigwork/nhgjrabl/Simulations/datamshapratirupa/5_calib/Case3_ces_calib/Case3_ces_start_cl.demo'

# %% [markdown]
# 1. Checks to be done:
#
# a. Check ats input file - .xml file
#
# b. TEMPCHEK - To check the template file
#
# c. INSCHEK - To check the instruction file
#
# d. Converting the file to version 1
#
# e. PESTCHEK - To check the pest control file

# %%
# Testing subprocess
subprocess.check_output(['ls', '-l'])
# Out:
# b'total 1372\n-rw-r--r-- 1 nhgjrabl NHGJ21622   3145 Aug 15 13:01 ats_modelcmd_cl.py\n-rw-r--r-- 1 nhgjrabl NHGJ21622   3027 Aug 15 13:26 ats_modelcmd.py\n-rw-r--r-- 1 nhgjrabl NHGJ21622   6004 Aug 15 13:01 ats_modelcmd_sd.py\n-rw-r--r-- 1 nhgjrabl NHGJ21622    425 Aug 15 13:20 Case3_ces_cf.pst\n-rw-r--r-- 1 nhgjrabl NHGJ21622 456628 Aug 15 13:01 Case3_ces_cf_v1.pst\n-rw-r--r-- 1 nhgjrabl NHGJ21622  84477 Aug 15 13:01 Case3_ces.dat.ins\n-rw-r--r-- 1 nhgjrabl NHGJ21622 112728 Aug 15 13:01 Case3_ces.dat.obf\n-rw-r--r-- 1 nhgjrabl NHGJ21622     71 Aug 15 13:18 Case3_ces.insfile.csv\n-rw-r--r-- 1 nhgjrabl NHGJ21622 294345 Aug 15 13:01 Case3_ces_obs_data.csv\n-rw-r--r-- 1 nhgjrabl NHGJ21622  88209 Aug 15 13:01 Case3_ces_obs_data.dat\n-rw-r--r-- 1 nhgjrabl NHGJ21622    846 Aug 15 13:01 Case3_ces_par_data.csv\n-rw-r--r-- 1 nhgjrabl NHGJ21622    621 Aug 15 13:01 Case3_ces_pargrp_data.csv\n-rw-r--r-- 1 nhgjrabl NHGJ21622     53 Aug 15 13:18 Case3_ces.tplfile.csv\n-rw-r--r-- 1 nhgjrabl NHGJ21622  67452 Aug 15 13:01 Case3_ces.xml\n-rw-r--r-- 1 nhgjrabl NHGJ21622  67471 Aug 15 13:11 Case3_ces.xml.tpl\n-rw-r--r-- 1 nhgjrabl NHGJ21622   1870 Aug 15 13:01 Generate_v1_pestfile.ipynb\n-rw-r--r-- 1 nhgjrabl NHGJ21622    690 Aug 15 13:01 slurm_script_pest_Case5_III.sh\ndrwxr-xr-x 2 nhgjrabl NHGJ21622  12288 Aug 15 13:01 test_ats_ces.demo\n-rw-r--r-- 1 nhgjrabl NHGJ21622 161037 Aug 15 13:25 Test_ats_results.ipynb\n'

# %%
### Running ats within a temp folder

subprocess.run(['mkdir','test_ats_ces.demo'], capture_output=True, text=True).stdout
# Out:
# ''

# %%
os.chdir('test_ats_ces.demo')

# %% [markdown]
# ##### We need to also run the simulations on the cluster, therefore we have created a seperate file where the data access changes!

# %%
file_name
# Out:
# 'Case3_ces'

# %%
# %%time
os.system(f'ats --xml_file=../{file_name}.xml')
# Out:
# CPU times: user 290 ms, sys: 68.4 ms, total: 358 ms
# Wall time: 2h 5min 12s
# 0

# %%
os.getcwd()
# Out:
# '/bigwork/nhgjrabl/Simulations/datamshapratirupa/5_calib/Case3_ces_calib/Case3_ces_start_cl.demo/test_ats_ces.demo'

# %%
sim_data = pd.read_csv('observations.dat',skiprows=88,sep=' ')
sim_data.tail()
# Out:
#        time [s]  point -0.04 temperature [K]  point -0.1 temperature [K]  \
# 362  31276800.0                   260.975771                  263.000860
# 363  31363200.0                   260.870439                  262.837087
# 364  31449600.0                   262.559182                  263.638890
# 365  31536000.0                   263.936511                  264.511465
# 366  31622400.0                   264.174788                  264.834764
#
#      point -0.2 temperature [K]  point -0.4 temperature [K]  \
# 362                  264.286990                  265.570829
# 363                  264.062113                  265.280525
# 364                  264.444968                  265.359456
# 365                  265.008509                  265.646354
# 366                  265.302178                  265.854330
#
#      point -0.8 temperature [K]  point -1.2 temperature [K]  \
# 362                  268.062549                  269.973285
# 363                  267.704482                  269.673589
# 364                  267.471620                  269.403328
# 365                  267.373929                  269.182109
# 366                  267.343253                  269.009905
#
#      point -1.6 temperature [K]  point -0.04 saturation liquid  \
# 362                  270.951904                       0.101576
# 363                  270.738094                       0.101569
# 364                  270.523824                       0.101689
# 365                  270.320445                       0.101811
# 366                  270.135692                       0.101834
#
#      point -0.1 saturation liquid  point -0.2 saturation liquid  \
# 362                      0.101725                      0.101846
# 363                      0.101712                      0.101823
# 364                      0.101782                      0.101863
# 365                      0.101870                      0.101926
# 366                      0.101906                      0.101961
#
#      point -0.4 saturation liquid  point -0.8 saturation liquid  \
# 362                      0.161270                      0.162369
# 363                      0.161177                      0.162165
# 364                      0.161200                      0.162043
# 365                      0.161292                      0.161993
# 366                      0.161363                      0.161977
#
#      point -1.2 saturation liquid  point -1.6 saturation liquid
# 362                      0.163965                      0.165498
# 363                      0.163630                      0.165085
# 364                      0.163362                      0.164723
# 365                      0.163164                      0.164418
# 366                      0.163020                      0.164167

# %%
os.getcwd()
# Out:
# '/bigwork/nhgjrabl/Simulations/datamshapratirupa/5_calib/Case3_ces_calib/Case3_ces_start_cl.demo/test_ats_ces.demo'

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
fig.set_size_inches(w=14,h=10)
fig.suptitle('Plotting temperature and saturation of liquid')

ax1.set_title('Soil temperature [K]')
#ax1.plot(sim_data['point -0.01 temperature [K]'],label='0.01 m')
ax1.plot(sim_data['point -0.04 temperature [K]'],label='0.04 m')
ax1.plot(sim_data['point -0.2 temperature [K]'],label='0.2 m')
ax1.plot(sim_data['point -0.4 temperature [K]'],label='0.4 m')
ax1.plot(sim_data['point -0.8 temperature [K]'],label='0.8 m')
ax1.plot(sim_data['point -1.2 temperature [K]'],label='1.2 m')
ax1.plot(sim_data['point -1.6 temperature [K]'],label='1.6 m')
#ax1.plot(sim_data['point -5.0 temperature [K]'],label='5.0 m')
#ax1.plot(sim_data['point -10.0 temperature [K]'],label='10.0 m')
#ax1.plot(sim_data['point -20.0 temperature [K]'],label='20.0 m')
#ax1.plot(sim_data['point -30.0 temperature [K]'],label='30.0 m')
#ax1.plot(sim_data['point -40.0 temperature [K]'],label='40.0 m')
ax1.set_ylabel('Temperature (K)')
#ax1.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
#ax1.set_xlabel('Date (days)')
ax1.legend(fontsize=8)
ax1.grid(True)

ax2.set_title('Plotting soil saturation liquid')
#ax2.plot(sim_data['point -0.01 saturation liquid'],label='0.01 m')
ax2.plot(sim_data['point -0.04 saturation liquid'],label='0.04 m')
ax2.plot(sim_data['point -0.2 saturation liquid'],label='0.2 m')
ax2.plot(sim_data['point -0.4 saturation liquid'],label='0.4 m')
ax2.plot(sim_data['point -0.8 saturation liquid'],label='0.8 m')
ax2.plot(sim_data['point -1.2 saturation liquid'],label='1.2 m')
ax2.plot(sim_data['point -1.6 saturation liquid'],label='1.6 m')
#ax2.plot(sim_data['point -5.0 saturation liquid'],label='5.0 m')
#ax2.plot(sim_data['point -10.0 saturation liquid'],label='10.0 m')

ax2.set_ylabel('Saturation of liquid (%)')
#ax2.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
#ax2.xlabel('Date (days)')
ax2.legend(fontsize=8)
ax2.grid(True)

# %%
file_name
# Out:
# 'Case3_ces'

# %%
sim_data_obs = pd.read_csv(f'{file_name}_obs_data.dat',sep=' ',header=None)
sim_data_obs.columns = sim_data.columns
sim_data_obs.head()
# Out:
#    time [s]  point -0.04 temperature [K]  point -0.1 temperature [K]  \
# 0       0.0                   260.207262                  261.547226
# 1   86400.0                   263.535879                  263.426567
# 2  172800.0                   262.571521                  263.256044
# 3  259200.0                   261.400921                  262.640519
# 4  345600.0                   261.861698                  262.762767
#
#    point -0.2 temperature [K]  point -0.4 temperature [K]  \
# 0                  262.513010                  263.441994
# 1                  263.582521                  263.938111
# 2                  263.689543                  264.132600
# 3                  263.374227                  264.013720
# 4                  263.390992                  263.992809
#
#    point -0.8 temperature [K]  point -1.2 temperature [K]  \
# 0                  265.332788                  267.094465
# 1                  265.285868                  266.938106
# 2                  265.336976                  266.843224
# 3                  265.321730                  266.766049
# 4                  265.288020                  266.694682
#
#    point -1.6 temperature [K]  point -0.04 saturation liquid  \
# 0                  268.276799                       6.471334
# 1                  268.131047                       6.486883
# 2                  268.005748                       6.481627
# 3                  267.896382                       6.476140
# 4                  267.798356                       6.478197
#
#    point -0.1 saturation liquid  point -0.2 saturation liquid  \
# 0                      6.476780                      6.481331
# 1                      6.486248                      6.487158
# 2                      6.485279                      6.487795
# 3                      6.481978                      6.485948
# 4                      6.482610                      6.486044
#
#    point -0.4 saturation liquid  point -0.8 saturation liquid  \
# 0                      7.729535                      7.753808
# 1                      7.735140                      7.753085
# 2                      7.737479                      7.753842
# 3                      7.736053                      7.753610
# 4                      7.735801                      7.753102
#
#    point -1.2 saturation liquid  point -1.6 saturation liquid
# 0                      7.785916                      7.816550
# 1                      7.782528                      7.812202
# 2                      7.780533                      7.808611
# 3                      7.778943                      7.805582
# 4                      7.777498                      7.802945

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
fig.set_size_inches(w=14,h=10)
fig.suptitle('Plotting temperature and saturation of liquid')

ax1.set_title('Soil temperature [K]')
#ax1.plot(sim_data_obs['point -0.01 temperature [K]'],label='0.01 m')
ax1.plot(sim_data_obs['point -0.04 temperature [K]'],label='0.04 m')
ax1.plot(sim_data_obs['point -0.2 temperature [K]'],label='0.2 m')
ax1.plot(sim_data_obs['point -0.4 temperature [K]'],label='0.4 m')
ax1.plot(sim_data_obs['point -0.8 temperature [K]'],label='0.8 m')
ax1.plot(sim_data_obs['point -1.2 temperature [K]'],label='1.2 m')
ax1.plot(sim_data_obs['point -1.6 temperature [K]'],label='1.6 m')
#ax1.plot(sim_data_obs['point -5.0 temperature [K]'],label='5.0 m')
#ax1.plot(sim_data_obs['point -10.0 temperature [K]'],label='10.0 m')
#ax1.plot(sim_data_obs['point -20.0 temperature [K]'],label='20.0 m')
#ax1.plot(sim_data_obs['point -30.0 temperature [K]'],label='30.0 m')
#ax1.plot(sim_data_obs['point -40.0 temperature [K]'],label='40.0 m')
ax1.set_ylabel('Temperature (K)')
#ax1.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
#ax1.set_xlabel('Date (days)')
ax1.legend(fontsize=8)
ax1.grid(True)

ax2.set_title('Plotting soil saturation liquid')
#ax2.plot(sim_data_obs['point -0.01 saturation liquid'],label='0.01 m')
ax2.plot(sim_data_obs['point -0.04 saturation liquid'],label='0.04 m')
ax2.plot(sim_data_obs['point -0.2 saturation liquid'],label='0.2 m')
ax2.plot(sim_data_obs['point -0.4 saturation liquid'],label='0.4 m')
ax2.plot(sim_data_obs['point -0.8 saturation liquid'],label='0.8 m')
ax2.plot(sim_data_obs['point -1.2 saturation liquid'],label='1.2 m')
ax2.plot(sim_data_obs['point -1.6 saturation liquid'],label='1.6 m')
#ax2.plot(sim_data_obs['point -5.0 saturation liquid'],label='5.0 m')
#ax2.plot(sim_data_obs['point -10.0 saturation liquid'],label='10.0 m')

ax2.set_ylabel('Saturation of liquid (%)')
#ax2.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))
#ax2.xlabel('Date (days)')
ax2.legend(fontsize=8)
ax2.grid(True)

# %% [markdown]
# Comments:
#
#     * The saturation of liquid is reaching one and hence ats is finding it hard to find a solution!

# %% [markdown]
# #### Check the outputs in the file and also the jupyter notebook terminal - weather it is running. If all is good you can start with the pestcheck!

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/bigwork/nhgjrabl/Simulations/datamshapratirupa/5_calib/Case3_ces_calib/Case3_ces_start_cl.demo'

# %%
# %%time
### Check the ats_modelcmd.py file - Change the file name line of peat and mineral
os.system('python3 ats_modelcmd_cl.py')
### Make sure that the observation file is created! - Testing in cmd is better
# Out:
# --------------------------------------------------------------------------
# By default, for Open MPI 4.0 and later, infiniband ports on a device
# are not used by default.  The intent is to use UCX for these devices.
# You can override this policy by setting the btl_openib_allow_ib MCA parameter
# to true.
#
#   Local host:              isu-n008
#   Local adapter:           mlx5_0
#   Local port:              1
#
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# WARNING: There was an error initializing an OpenFabrics device.
#
#   Local host:   isu-n008
#   Local device: mlx5_0
# --------------------------------------------------------------------------
# Simulation Driver  |  ======================> dumping parameter list <======================
# Simulation Driver  |  <ParameterList name="ANONYMOUS">
# Simulation Driver  |    <ParameterList id="15" name="mesh">
# Simulation Driver  |      <ParameterList id="6" name="domain">
# Simulation Driver  |        <Parameter docString="" id="0" isDefault="false" isUsed="true" name="mesh type" type="string" value="generate mesh"/>
# Simulation Driver  |        <Parameter docString="" id="1" isDefault="false" isUsed="true" name="build columns from set" type="string" value="surface face"/>
# Simulation Driver  |        <ParameterList id="5" name="generate mesh parameters">
# Simulation Driver  |          <Parameter docString="" id="2" isDefault="false" isUsed="true" name="number of cells" type="Array(int)" value="{1, 1, 400}"/>
# Simulation Driver  |          <Parameter docString="" id="3" isDefault="false" isUsed="true" name="domain low coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 0.00000000000000000e+00}"/>
# Simulation Driver  |          <Parameter docString="" id="4" isDefault="false" isUsed="true" name="domain high coordinate" type="Array(double)" value="{1.00000000000000000e+00, 1.00000000000000000e+00, 4.00000000000000000e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="10" name="surface">
# Simulation Driver  |        <Parameter docString="" id="7" isDefault="false" isUsed="true" name="mesh type" type="string" value="surface"/>
# Simulation Driver  |        <ParameterList id="9" name="surface parameters">
# Simulation Driver  |          <Parameter docString="" id="8" isDefault="false" isUsed="true" name="surface sideset name" type="string" value="surface face"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="14" name="snow">
# Simulation Driver  |        <Parameter docString="" id="11" isDefault="false" isUsed="true" name="mesh type" type="string" value="aliased"/>
# Simulation Driver  |        <ParameterList id="13" name="aliased parameters">
# Simulation Driver  |          <Parameter docString="" id="12" isDefault="false" isUsed="true" name="target" type="string" value="surface"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |    </ParameterList>
# Simulation Driver  |    <ParameterList id="81" name="regions">
# Simulation Driver  |      <ParameterList id="17" name="domain">
# Simulation Driver  |        <ParameterList id="16" name="region: all"/>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="19" name="surface domain">
# Simulation Driver  |        <ParameterList id="18" name="region: all"/>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="23" name="subsurface domain bedrock">
# Simulation Driver  |        <ParameterList id="22" name="region: box">
# Simulation Driver  |          <Parameter docString="" id="20" isDefault="false" isUsed="true" name="low coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 0.00000000000000000e+00}"/>
# Simulation Driver  |          <Parameter docString="" id="21" isDefault="false" isUsed="true" name="high coordinate" type="Array(double)" value="{1.00000000000000000e+00, 1.00000000000000000e+00, 2.00000000000000000e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="27" name="subsurface domain mineral">
# Simulation Driver  |        <ParameterList id="26" name="region: box">
# Simulation Driver  |          <Parameter docString="" id="24" isDefault="false" isUsed="true" name="low coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 2.00000000000000000e+01}"/>
# Simulation Driver  |          <Parameter docString="" id="25" isDefault="false" isUsed="true" name="high coordinate" type="Array(double)" value="{1.00000000000000000e+00, 1.00000000000000000e+00, 3.97000000000000028e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="31" name="subsurface domain peat">
# Simulation Driver  |        <ParameterList id="30" name="region: box">
# Simulation Driver  |          <Parameter docString="" id="28" isDefault="false" isUsed="true" name="low coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.97000000000000028e+01}"/>
# Simulation Driver  |          <Parameter docString="" id="29" isDefault="false" isUsed="true" name="high coordinate" type="Array(double)" value="{1.00000000000000000e+00, 1.00000000000000000e+00, 4.00000000000000000e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="35" name="surface face">
# Simulation Driver  |        <ParameterList id="34" name="region: plane">
# Simulation Driver  |          <Parameter docString="" id="32" isDefault="false" isUsed="true" name="point" type="Array(double)" value="{5.00000000000000000e-01, 5.00000000000000000e-01, 4.00000000000000000e+01}"/>
# Simulation Driver  |          <Parameter docString="" id="33" isDefault="false" isUsed="true" name="normal" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 1.00000000000000000e+00}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="39" name="bottom face">
# Simulation Driver  |        <ParameterList id="38" name="region: plane">
# Simulation Driver  |          <Parameter docString="" id="36" isDefault="false" isUsed="true" name="point" type="Array(double)" value="{5.00000000000000000e-01, 5.00000000000000000e-01, 0.00000000000000000e+00}"/>
# Simulation Driver  |          <Parameter docString="" id="37" isDefault="false" isUsed="true" name="normal" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, -1.00000000000000000e+00}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="42" name="subsurface point -0.01">
# Simulation Driver  |        <ParameterList id="41" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="40" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.99900000000000020e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="45" name="subsurface point -0.04">
# Simulation Driver  |        <ParameterList id="44" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="43" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.99600000000000009e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="48" name="subsurface point -0.1">
# Simulation Driver  |        <ParameterList id="47" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="46" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.98999999999999986e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="51" name="subsurface point -0.2">
# Simulation Driver  |        <ParameterList id="50" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="49" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.97999999999999972e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="54" name="subsurface point -0.4">
# Simulation Driver  |        <ParameterList id="53" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="52" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.96000000000000014e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="57" name="subsurface point -0.8">
# Simulation Driver  |        <ParameterList id="56" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="55" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.92000000000000028e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="60" name="subsurface point -1.2">
# Simulation Driver  |        <ParameterList id="59" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="58" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.87999999999999972e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="63" name="subsurface point -1.6">
# Simulation Driver  |        <ParameterList id="62" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="61" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.83999999999999986e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="66" name="subsurface point -5.0">
# Simulation Driver  |        <ParameterList id="65" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="64" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.50000000000000000e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="69" name="subsurface point -10.0">
# Simulation Driver  |        <ParameterList id="68" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="67" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 3.00000000000000000e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="72" name="subsurface point -20.0">
# Simulation Driver  |        <ParameterList id="71" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="70" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 2.00000000000000000e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="75" name="subsurface point -30.0">
# Simulation Driver  |        <ParameterList id="74" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="73" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 1.00000000000000000e+01}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="78" name="subsurface point -40.0">
# Simulation Driver  |        <ParameterList id="77" name="region: point">
# Simulation Driver  |          <Parameter docString="" id="76" isDefault="false" isUsed="true" name="coordinate" type="Array(double)" value="{0.00000000000000000e+00, 0.00000000000000000e+00, 0.00000000000000000e+00}"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="80" name="surface outlet">
# Simulation Driver  |        <ParameterList id="79" name="region: boundary"/>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |    </ParameterList>
# Simulation Driver  |    <ParameterList id="101" name="cycle driver">
# Simulation Driver  |      <Parameter docString="" id="82" isDefault="false" isUsed="true" name="start time" type="double" value="0.00000000000000000e+00"/>
# Simulation Driver  |      <Parameter docString="" id="83" isDefault="false" isUsed="true" name="start time units" type="string" value="d"/>
# Simulation Driver  |      <Parameter docString="" id="84" isDefault="false" isUsed="true" name="end time" type="double" value="3.66000000000000000e+02"/>
# Simulation Driver  |      <Parameter docString="" id="85" isDefault="false" isUsed="true" name="end time units" type="string" value="d"/>
# Simulation Driver  |      <ParameterList id="100" name="PK tree">
# Simulation Driver  |        <ParameterList id="99" name="top level MPC">
# Simulation Driver  |          <Parameter docString="" id="86" isDefault="false" isUsed="true" name="PK type" type="string" value="strong MPC"/>
# Simulation Driver  |          <ParameterList id="88" name="SEB">
# Simulation Driver  |            <Parameter docString="" id="87" isDefault="false" isUsed="true" name="PK type" type="string" value="surface balance implicit subgrid"/>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |          <ParameterList id="98" name="permafrost surface and subsurface">
# Simulation Driver  |            <Parameter docString="" id="89" isDefault="false" isUsed="true" name="PK type" type="string" value="permafrost model"/>
# Simulation Driver  |            <ParameterList id="91" name="subsurface flow">
# Simulation Driver  |              <Parameter docString="" id="90" isDefault="false" isUsed="true" name="PK type" type="string" value="permafrost flow"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |            <ParameterList id="93" name="surface flow">
# Simulation Driver  |              <Parameter docString="" id="92" isDefault="false" isUsed="true" name="PK type" type="string" value="overland flow with ice"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |            <ParameterList id="95" name="subsurface energy">
# Simulation Driver  |              <Parameter docString="" id="94" isDefault="false" isUsed="true" name="PK type" type="string" value="three-phase energy"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |            <ParameterList id="97" name="surface energy">
# Simulation Driver  |              <Parameter docString="" id="96" isDefault="false" isUsed="true" name="PK type" type="string" value="surface energy"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |    </ParameterList>
# Simulation Driver  |    <ParameterList id="337" name="PKs">
# Simulation Driver  |      <ParameterList id="132" name="top level MPC">
# Simulation Driver  |        <Parameter docString="" id="102" isDefault="false" isUsed="true" name="PK type" type="string" value="strong MPC"/>
# Simulation Driver  |        <Parameter docString="" id="103" isDefault="false" isUsed="true" name="PKs order" type="Array(string)" value="{SEB, permafrost surface and subsurface}"/>
# Simulation Driver  |        <ParameterList id="105" name="verbose object">
# Simulation Driver  |          <Parameter docString="" id="104" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="131" name="time integrator">
# Simulation Driver  |          <Parameter docString="" id="106" isDefault="false" isUsed="true" name="extrapolate initial guess" type="bool" value="true"/>
# Simulation Driver  |          <Parameter docString="" id="107" isDefault="false" isUsed="true" name="solver type" type="string" value="nka_bt_ats"/>
# Simulation Driver  |          <Parameter docString="" id="108" isDefault="false" isUsed="true" name="timestep controller type" type="string" value="smarter"/>
# Simulation Driver  |          <ParameterList id="119" name="nka_bt_ats parameters">
# Simulation Driver  |            <Parameter docString="" id="109" isDefault="false" isUsed="true" name="nka lag iterations" type="int" value="2"/>
# Simulation Driver  |            <Parameter docString="" id="110" isDefault="false" isUsed="true" name="max backtrack steps" type="int" value="5"/>
# Simulation Driver  |            <Parameter docString="" id="111" isDefault="false" isUsed="true" name="backtrack lag" type="int" value="0"/>
# Simulation Driver  |            <Parameter docString="" id="112" isDefault="false" isUsed="true" name="backtrack factor" type="double" value="5.00000000000000000e-01"/>
# Simulation Driver  |            <Parameter docString="" id="113" isDefault="false" isUsed="true" name="backtrack tolerance" type="double" value="1.00000000000000005e-04"/>
# Simulation Driver  |            <Parameter docString="" id="114" isDefault="false" isUsed="true" name="nonlinear tolerance" type="double" value="9.99999999999999955e-07"/>
# Simulation Driver  |            <Parameter docString="" id="115" isDefault="false" isUsed="true" name="diverged tolerance" type="double" value="1.00000000000000000e+05"/>
# Simulation Driver  |            <Parameter docString="" id="116" isDefault="false" isUsed="true" name="limit iterations" type="int" value="21"/>
# Simulation Driver  |            <ParameterList id="118" name="verbose object">
# Simulation Driver  |              <Parameter docString="" id="117" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |          <ParameterList id="121" name="verbose object">
# Simulation Driver  |            <Parameter docString="" id="120" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |          <ParameterList id="130" name="timestep controller smarter parameters">
# Simulation Driver  |            <Parameter docString="" id="122" isDefault="false" isUsed="true" name="max iterations" type="int" value="18"/>
# Simulation Driver  |            <Parameter docString="" id="123" isDefault="false" isUsed="true" name="min iterations" type="int" value="10"/>
# Simulation Driver  |            <Parameter docString="" id="124" isDefault="false" isUsed="true" name="time step reduction factor" type="double" value="5.00000000000000000e-01"/>
# Simulation Driver  |            <Parameter docString="" id="125" isDefault="false" isUsed="true" name="time step increase factor" type="double" value="1.50000000000000000e+00"/>
# Simulation Driver  |            <Parameter docString="" id="126" isDefault="false" isUsed="true" name="max time step" type="double" value="1.00000000000000000e+08"/>
# Simulation Driver  |            <Parameter docString="" id="127" isDefault="false" isUsed="true" name="min time step" type="double" value="1.00000000000000004e-10"/>
# Simulation Driver  |            <Parameter docString="" id="128" isDefault="false" isUsed="true" name="growth wait after fail" type="int" value="2"/>
# Simulation Driver  |            <Parameter docString="" id="129" isDefault="false" isUsed="true" name="count before increasing increase factor" type="int" value="2"/>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="173" name="permafrost surface and subsurface">
# Simulation Driver  |        <Parameter docString="" id="133" isDefault="false" isUsed="true" name="PK type" type="string" value="permafrost model"/>
# Simulation Driver  |        <Parameter docString="" id="134" isDefault="false" isUsed="true" name="PKs order" type="Array(string)" value="{subsurface flow, subsurface energy, surface flow, surface energy}"/>
# Simulation Driver  |        <Parameter docString="" id="135" isDefault="false" isUsed="true" name="preconditioner type" type="string" value="picard"/>
# Simulation Driver  |        <Parameter docString="" id="136" isDefault="false" isUsed="true" name="supress Jacobian terms: d div q / dT" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="137" isDefault="false" isUsed="true" name="supress Jacobian terms: d div surface q / dT" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="138" isDefault="false" isUsed="true" name="supress Jacobian terms: d div K grad T / dp" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="139" isDefault="false" isUsed="true" name="supress Jacobian terms: d div hq / dp,T" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="140" isDefault="false" isUsed="true" name="dump preconditioner" type="bool" value="false"/>
# Simulation Driver  |        <ParameterList id="142" name="verbose object">
# Simulation Driver  |          <Parameter docString="" id="141" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="148" name="ewc delegate">
# Simulation Driver  |          <Parameter docString="" id="143" isDefault="false" isUsed="true" name="predictor type" type="string" value="smart ewc"/>
# Simulation Driver  |          <Parameter docString="" id="144" isDefault="false" isUsed="true" name="use pc_ice to determine sfc" type="bool" value="true"/>
# Simulation Driver  |          <Parameter docString="" id="145" isDefault="false" isUsed="true" name="freeze-thaw cusp width [K]" type="double" value="1.00000000000000000e+00"/>
# Simulation Driver  |          <ParameterList id="147" name="verbose object">
# Simulation Driver  |            <Parameter docString="" id="146" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="153" name="water delegate">
# Simulation Driver  |          <Parameter docString="" id="149" isDefault="false" isUsed="true" name="modify predictor damp and cap the water spurt" type="bool" value="true"/>
# Simulation Driver  |          <Parameter docString="" id="150" isDefault="false" isUsed="true" name="damp and cap the water spurt" type="bool" value="true"/>
# Simulation Driver  |          <Parameter docString="" id="151" isDefault="false" isUsed="true" name="damp and cap the saturated spurt" type="bool" value="true"/>
# Simulation Driver  |          <Parameter docString="" id="152" isDefault="false" isUsed="true" name="cap over atmospheric" type="double" value="1.00000000000000005e-04"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="172" name="inverse">
# Simulation Driver  |          <Parameter docString="" id="154" isDefault="false" isUsed="true" name="preconditioning method" type="string" value="boomer amg"/>
# Simulation Driver  |          <Parameter docString="" id="155" isDefault="false" isUsed="true" name="iterative method" type="string" value="gmres"/>
# Simulation Driver  |          <ParameterList id="162" name="boomer amg parameters">
# Simulation Driver  |            <Parameter docString="" id="156" isDefault="false" isUsed="true" name="cycle applications" type="int" value="1"/>
# Simulation Driver  |            <Parameter docString="" id="157" isDefault="false" isUsed="true" name="smoother sweeps" type="int" value="1"/>
# Simulation Driver  |            <Parameter docString="" id="158" isDefault="false" isUsed="true" name="strong threshold" type="double" value="6.50000000000000022e-01"/>
# Simulation Driver  |            <Parameter docString="" id="159" isDefault="false" isUsed="true" name="tolerance" type="double" value="0.00000000000000000e+00"/>
# Simulation Driver  |            <Parameter docString="" id="160" isDefault="false" isUsed="true" name="number of functions" type="int" value="2"/>
# Simulation Driver  |            <Parameter docString="" id="161" isDefault="false" isUsed="true" name="verbosity" type="int" value="0"/>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |          <ParameterList id="164" name="verbose object">
# Simulation Driver  |            <Parameter docString="" id="163" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |          <ParameterList id="171" name="gmres parameters">
# Simulation Driver  |            <Parameter docString="" id="165" isDefault="false" isUsed="true" name="preconditioning strategy" type="string" value="left"/>
# Simulation Driver  |            <Parameter docString="" id="166" isDefault="false" isUsed="true" name="error tolerance" type="double" value="9.99999999999999955e-07"/>
# Simulation Driver  |            <Parameter docString="" id="167" isDefault="false" isUsed="true" name="convergence criteria" type="Array(string)" value="{relative residual, make one iteration}"/>
# Simulation Driver  |            <Parameter docString="" id="168" isDefault="false" isUsed="true" name="maximum number of iteration" type="int" value="80"/>
# Simulation Driver  |            <ParameterList id="170" name="verbose object">
# Simulation Driver  |              <Parameter docString="" id="169" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="224" name="subsurface flow">
# Simulation Driver  |        <Parameter docString="" id="174" isDefault="false" isUsed="true" name="PK type" type="string" value="permafrost flow"/>
# Simulation Driver  |        <Parameter docString="" id="175" isDefault="false" isUsed="true" name="primary variable key" type="string" value="pressure"/>
# Simulation Driver  |        <Parameter docString="" id="176" isDefault="false" isUsed="true" name="domain name" type="string" value="domain"/>
# Simulation Driver  |        <Parameter docString="" id="177" isDefault="false" isUsed="true" name="source term" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="178" isDefault="false" isUsed="true" name="source key" type="string" value="water_source"/>
# Simulation Driver  |        <Parameter docString="" id="179" isDefault="false" isUsed="true" name="source term is differentiable" type="bool" value="false"/>
# Simulation Driver  |        <Parameter docString="" id="180" isDefault="false" isUsed="true" name="permeability rescaling" type="double" value="1.00000000000000000e+07"/>
# Simulation Driver  |        <Parameter docString="" id="181" isDefault="false" isUsed="true" name="relative permeability method" type="string" value="upwind with Darcy flux"/>
# Simulation Driver  |        <Parameter docString="" id="182" isDefault="false" isUsed="true" name="surface rel perm strategy" type="string" value="unsaturated"/>
# Simulation Driver  |        <Parameter docString="" id="183" isDefault="false" isUsed="true" name="max valid change in saturation in a time step [-]" type="double" value="1.00000000000000006e-01"/>
# Simulation Driver  |        <Parameter docString="" id="184" isDefault="false" isUsed="true" name="max valid change in ice saturation in a time step [-]" type="double" value="1.00000000000000006e-01"/>
# Simulation Driver  |        <Parameter docString="" id="185" isDefault="false" isUsed="true" name="initial time step" type="double" value="8.64000000000000000e+04"/>
# Simulation Driver  |        <ParameterList id="187" name="verbose object">
# Simulation Driver  |          <Parameter docString="" id="186" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="189" name="diffusion">
# Simulation Driver  |          <Parameter docString="" id="188" isDefault="false" isUsed="true" name="discretization primary" type="string" value="mfd: two-point flux approximation"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="191" name="diffusion preconditioner">
# Simulation Driver  |          <Parameter docString="" id="190" isDefault="false" isUsed="true" name="include Newton correction" type="bool" value="true"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="192" name="boundary conditions"/>
# Simulation Driver  |        <ParameterList id="194" name="initial condition">
# Simulation Driver  |          <Parameter docString="" id="193" isDefault="false" isUsed="true" name="restart file" type="string" value="../../../3_spinup/Case3_ces_dynamic_spinup.demo/checkpoint_final.h5"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="223" name="water retention evaluator">
# Simulation Driver  |          <Parameter docString="" id="195" isDefault="false" isUsed="true" name="minimum rel perm cutoff" type="double" value="0.00000000000000000e+00"/>
# Simulation Driver  |          <Parameter docString="" id="196" isDefault="false" isUsed="true" name="use surface rel perm" type="bool" value="true"/>
# Simulation Driver  |          <Parameter docString="" id="197" isDefault="false" isUsed="true" name="liquid-ice capillary pressure key" type="string" value="capillary_pressure_liq_ice"/>
# Simulation Driver  |          <ParameterList id="219" name="WRM parameters">
# Simulation Driver  |            <ParameterList id="204" name="peat">
# Simulation Driver  |              <Parameter docString="" id="198" isDefault="false" isUsed="true" name="region" type="string" value="subsurface domain peat"/>
# Simulation Driver  |              <Parameter docString="" id="199" isDefault="false" isUsed="true" name="WRM Type" type="string" value="van Genuchten"/>
# Simulation Driver  |              <Parameter docString="" id="200" isDefault="false" isUsed="true" name="van Genuchten alpha [Pa^-1]" type="double" value="1.00000000000000002e-02"/>
# Simulation Driver  |              <Parameter docString="" id="201" isDefault="false" isUsed="true" name="van Genuchten n [-]" type="double" value="1.50000000000000000e+00"/>
# Simulation Driver  |              <Parameter docString="" id="202" isDefault="false" isUsed="true" name="residual saturation [-]" type="double" value="1.00000000000000006e-01"/>
# Simulation Driver  |              <Parameter docString="" id="203" isDefault="false" isUsed="true" name="smoothing interval width [saturation]" type="double" value="1.00000000000000006e-01"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |            <ParameterList id="211" name="mineral">
# Simulation Driver  |              <Parameter docString="" id="205" isDefault="false" isUsed="true" name="region" type="string" value="subsurface domain mineral"/>
# Simulation Driver  |              <Parameter docString="" id="206" isDefault="false" isUsed="true" name="WRM Type" type="string" value="van Genuchten"/>
# Simulation Driver  |              <Parameter docString="" id="207" isDefault="false" isUsed="true" name="van Genuchten alpha [Pa^-1]" type="double" value="1.82491440000000010e-03"/>
# Simulation Driver  |              <Parameter docString="" id="208" isDefault="false" isUsed="true" name="van Genuchten n [-]" type="double" value="1.48459000000000008e+00"/>
# Simulation Driver  |              <Parameter docString="" id="209" isDefault="false" isUsed="true" name="residual saturation [-]" type="double" value="1.56116000000000005e-01"/>
# Simulation Driver  |              <Parameter docString="" id="210" isDefault="false" isUsed="true" name="smoothing interval width [saturation]" type="double" value="1.00000000000000006e-01"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |            <ParameterList id="218" name="bedrock">
# Simulation Driver  |              <Parameter docString="" id="212" isDefault="false" isUsed="true" name="region" type="string" value="subsurface domain bedrock"/>
# Simulation Driver  |              <Parameter docString="" id="213" isDefault="false" isUsed="true" name="WRM Type" type="string" value="van Genuchten"/>
# Simulation Driver  |              <Parameter docString="" id="214" isDefault="false" isUsed="true" name="van Genuchten alpha [Pa^-1]" type="double" value="2.99999999999999989e-02"/>
# Simulation Driver  |              <Parameter docString="" id="215" isDefault="false" isUsed="true" name="van Genuchten n [-]" type="double" value="2.00000000000000000e+00"/>
# Simulation Driver  |              <Parameter docString="" id="216" isDefault="false" isUsed="true" name="residual saturation [-]" type="double" value="5.00000000000000028e-02"/>
# Simulation Driver  |              <Parameter docString="" id="217" isDefault="false" isUsed="true" name="smoothing interval width [saturation]" type="double" value="1.00000000000000006e-01"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |          <ParameterList id="222" name="permafrost model parameters">
# Simulation Driver  |            <Parameter docString="" id="220" isDefault="false" isUsed="true" name="permafrost WRM type" type="string" value="fpd permafrost model"/>
# Simulation Driver  |            <Parameter docString="" id="221" isDefault="false" isUsed="true" name="minimum dsi_dpressure magnitude" type="double" value="9.99999999999999980e-13"/>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="246" name="surface flow">
# Simulation Driver  |        <Parameter docString="" id="225" isDefault="false" isUsed="true" name="PK type" type="string" value="overland flow with ice"/>
# Simulation Driver  |        <Parameter docString="" id="226" isDefault="false" isUsed="true" name="domain name" type="string" value="surface"/>
# Simulation Driver  |        <Parameter docString="" id="227" isDefault="false" isUsed="true" name="primary variable key" type="string" value="surface-pressure"/>
# Simulation Driver  |        <Parameter docString="" id="228" isDefault="false" isUsed="true" name="source term" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="229" isDefault="false" isUsed="true" name="source key" type="string" value="surface-water_source"/>
# Simulation Driver  |        <Parameter docString="" id="230" isDefault="false" isUsed="true" name="source term is differentiable" type="bool" value="false"/>
# Simulation Driver  |        <Parameter docString="" id="231" isDefault="false" isUsed="true" name="mass source in meters" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="232" isDefault="false" isUsed="true" name="initial time step" type="double" value="8.64000000000000000e+04"/>
# Simulation Driver  |        <ParameterList id="234" name="verbose object">
# Simulation Driver  |          <Parameter docString="" id="233" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="236" name="diffusion">
# Simulation Driver  |          <Parameter docString="" id="235" isDefault="false" isUsed="true" name="discretization primary" type="string" value="fv: default"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="243" name="boundary conditions">
# Simulation Driver  |          <ParameterList id="242" name="seepage face head">
# Simulation Driver  |            <ParameterList id="241" name="surface outlet">
# Simulation Driver  |              <Parameter docString="" id="237" isDefault="false" isUsed="true" name="regions" type="Array(string)" value="{surface outlet}"/>
# Simulation Driver  |              <ParameterList id="240" name="boundary head">
# Simulation Driver  |                <ParameterList id="239" name="function-constant">
# Simulation Driver  |                  <Parameter docString="" id="238" isDefault="false" isUsed="true" name="value" type="double" value="0.00000000000000000e+00"/>
# Simulation Driver  |                </ParameterList>
# Simulation Driver  |              </ParameterList>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="245" name="initial condition">
# Simulation Driver  |          <Parameter docString="" id="244" isDefault="false" isUsed="true" name="initialize surface head from subsurface" type="bool" value="true"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="295" name="subsurface energy">
# Simulation Driver  |        <Parameter docString="" id="247" isDefault="false" isUsed="true" name="PK type" type="string" value="three-phase energy"/>
# Simulation Driver  |        <Parameter docString="" id="248" isDefault="false" isUsed="true" name="domain name" type="string" value="domain"/>
# Simulation Driver  |        <Parameter docString="" id="249" isDefault="false" isUsed="true" name="primary variable key" type="string" value="temperature"/>
# Simulation Driver  |        <Parameter docString="" id="250" isDefault="false" isUsed="true" name="source term" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="251" isDefault="false" isUsed="true" name="source key" type="string" value="total_energy_source"/>
# Simulation Driver  |        <Parameter docString="" id="252" isDefault="false" isUsed="true" name="source term is differentiable" type="bool" value="false"/>
# Simulation Driver  |        <Parameter docString="" id="253" isDefault="false" isUsed="true" name="initial time step" type="double" value="8.64000000000000000e+04"/>
# Simulation Driver  |        <Parameter docString="" id="254" isDefault="false" isUsed="true" name="include thermal advection" type="bool" value="false"/>
# Simulation Driver  |        <Parameter docString="" id="255" isDefault="false" isUsed="true" name="explicit advection" type="bool" value="false"/>
# Simulation Driver  |        <Parameter docString="" id="256" isDefault="false" isUsed="true" name="supress advective terms in preconditioner" type="bool" value="true"/>
# Simulation Driver  |        <ParameterList id="258" name="verbose object">
# Simulation Driver  |          <Parameter docString="" id="257" isDefault="false" isUsed="true" name="verbosity level" type="string" value="low"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="260" name="diffusion">
# Simulation Driver  |          <Parameter docString="" id="259" isDefault="false" isUsed="true" name="discretization primary" type="string" value="mfd: two-point flux approximation"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="267" name="boundary conditions">
# Simulation Driver  |          <ParameterList id="266" name="temperature">
# Simulation Driver  |            <ParameterList id="265" name="bottom">
# Simulation Driver  |              <Parameter docString="" id="261" isDefault="false" isUsed="true" name="regions" type="Array(string)" value="{bottom face}"/>
# Simulation Driver  |              <ParameterList id="264" name="boundary temperature">
# Simulation Driver  |                <ParameterList id="263" name="function-constant">
# Simulation Driver  |                  <Parameter docString="" id="262" isDefault="false" isUsed="true" name="value" type="double" value="2.68449999999999989e+02"/>
# Simulation Driver  |                </ParameterList>
# Simulation Driver  |              </ParameterList>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="269" name="initial condition">
# Simulation Driver  |          <Parameter docString="" id="268" isDefault="false" isUsed="true" name="restart file" type="string" value="../../../3_spinup/Case3_ces_dynamic_spinup.demo/checkpoint_final.h5"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="292" name="thermal conductivity evaluator">
# Simulation Driver  |          <ParameterList id="291" name="thermal conductivity parameters">
# Simulation Driver  |            <ParameterList id="276" name="peat">
# Simulation Driver  |              <Parameter docString="" id="270" isDefault="false" isUsed="true" name="region" type="string" value="subsurface domain peat"/>
# Simulation Driver  |              <Parameter docString="" id="271" isDefault="false" isUsed="true" name="thermal conductivity type" type="string" value="three-phase wet/dry"/>
# Simulation Driver  |              <Parameter docString="" id="272" isDefault="false" isUsed="true" name="thermal conductivity, saturated (unfrozen) [W m^-1 K^-1]" type="double" value="4.91954999999999976e-01"/>
# Simulation Driver  |              <Parameter docString="" id="273" isDefault="false" isUsed="true" name="thermal conductivity, dry [W m^-1 K^-1]" type="double" value="1.20658000000000001e-01"/>
# Simulation Driver  |              <Parameter docString="" id="274" isDefault="false" isUsed="true" name="unsaturated alpha frozen [-]" type="double" value="1.49655000000000005e+00"/>
# Simulation Driver  |              <Parameter docString="" id="275" isDefault="false" isUsed="true" name="unsaturated alpha unfrozen [-]" type="double" value="4.77138000000000007e-01"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |            <ParameterList id="283" name="mineral">
# Simulation Driver  |              <Parameter docString="" id="277" isDefault="false" isUsed="true" name="region" type="string" value="subsurface domain mineral"/>
# Simulation Driver  |              <Parameter docString="" id="278" isDefault="false" isUsed="true" name="thermal conductivity type" type="string" value="three-phase wet/dry"/>
# Simulation Driver  |              <Parameter docString="" id="279" isDefault="false" isUsed="true" name="thermal conductivity, saturated (unfrozen) [W m^-1 K^-1]" type="double" value="9.38163999999999998e-01"/>
# Simulation Driver  |              <Parameter docString="" id="280" isDefault="false" isUsed="true" name="thermal conductivity, dry [W m^-1 K^-1]" type="double" value="9.84400000000000053e-01"/>
# Simulation Driver  |              <Parameter docString="" id="281" isDefault="false" isUsed="true" name="unsaturated alpha frozen [-]" type="double" value="1.49909000000000003e+00"/>
# Simulation Driver  |              <Parameter docString="" id="282" isDefault="false" isUsed="true" name="unsaturated alpha unfrozen [-]" type="double" value="6.99200000000000044e-01"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |            <ParameterList id="290" name="bedrock">
# Simulation Driver  |              <Parameter docString="" id="284" isDefault="false" isUsed="true" name="region" type="string" value="subsurface domain bedrock"/>
# Simulation Driver  |              <Parameter docString="" id="285" isDefault="false" isUsed="true" name="thermal conductivity type" type="string" value="three-phase wet/dry"/>
# Simulation Driver  |              <Parameter docString="" id="286" isDefault="false" isUsed="true" name="thermal conductivity, saturated (unfrozen) [W m^-1 K^-1]" type="double" value="1.00000000000000000e+00"/>
# Simulation Driver  |              <Parameter docString="" id="287" isDefault="false" isUsed="true" name="thermal conductivity, dry [W m^-1 K^-1]" type="double" value="2.89999999999999980e-01"/>
# Simulation Driver  |              <Parameter docString="" id="288" isDefault="false" isUsed="true" name="unsaturated alpha frozen [-]" type="double" value="1.00000000000000000e+00"/>
# Simulation Driver  |              <Parameter docString="" id="289" isDefault="false" isUsed="true" name="unsaturated alpha unfrozen [-]" type="double" value="5.00000000000000000e-01"/>
# Simulation Driver  |            </ParameterList>
# Simulation Driver  |          </ParameterList>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |        <ParameterList id="294" name="enthalpy evaluator">
# Simulation Driver  |          <Parameter docString="" id="293" isDefault="false" isUsed="true" name="include work term" type="bool" value="false"/>
# Simulation Driver  |        </ParameterList>
# Simulation Driver  |      </ParameterList>
# Simulation Driver  |      <ParameterList id="321" name="surface energy">
# Simulation Driver  |        <Parameter docString="" id="296" isDefault="false" isUsed="true" name="PK type" type="string" value="surface energy"/>
# Simulation Driver  |        <Parameter docString="" id="297" isDefault="false" isUsed="true" name="domain name" type="string" value="surface"/>
# Simulation Driver  |        <Parameter docString="" id="298" isDefault="false" isUsed="true" name="primary variable key" type="string" value="surface-temperature"/>
# Simulation Driver  |        <Parameter docString="" id="299" isDefault="false" isUsed="true" name="source term" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="300" isDefault="false" isUsed="true" name="source key" type="string" value="surface-total_energy_source"/>
# Simulation Driver  |        <Parameter docString="" id="301" isDefault="false" isUsed="true" name="source term is differentiable" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="302" isDefault="false" isUsed="true" name="source term finite difference" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="303" isDefault="false" isUsed="true" name="flux key" type="string" value="surface-mass_flux"/>
# Simulation Driver  |        <Parameter docString="" id="304" isDefault="false" isUsed="true" name="include thermal advection" type="bool" value="false"/>
# Simulation Driver  |        <Parameter docString="" id="305" isDefault="false" isUsed="true" name="explicit advection" type="bool" value="false"/>
# Simulation Driver  |        <Parameter docString="" id="306" isDefault="false" isUsed="true" name="supress advective terms in preconditioner" type="bool" value="true"/>
# Simulation Driver  |        <Parameter docString="" id="307" isDefault="false" isUsed="true" name="upwind conductivity method" type="string" value="arithmetic mean"/>
# ...
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 29721600 t1 = 29808000 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 11 iterations, error = 5.568354197943892e-08
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 512,  Time [days] = 345,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 29808000 t1 = 29894400 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 9 iterations, error = 6.693555993220785e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 513,  Time [days] = 346,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 29894400 t1 = 29980800 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 12 iterations, error = 5.997366723322941e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 514,  Time [days] = 347,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 29980800 t1 = 30067200 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 8 iterations, error = 9.757057309421471e-08
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 515,  Time [days] = 348,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30067200 t1 = 30153600 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 8 iterations, error = 2.240787391407355e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 516,  Time [days] = 349,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30153600 t1 = 30240000 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 9 iterations, error = 5.868099564590532e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 517,  Time [days] = 350,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30240000 t1 = 30326400 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 10 iterations, error = 3.879350231640563e-08
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 518,  Time [days] = 351,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30326400 t1 = 30412800 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 8 iterations, error = 2.809390225602314e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 519,  Time [days] = 352,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30412800 t1 = 30499200 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 10 iterations, error = 5.11224585500271e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 520,  Time [days] = 353,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30499200 t1 = 30585600 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 8 iterations, error = 3.562265422610819e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 521,  Time [days] = 354,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30585600 t1 = 30672000 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 9 iterations, error = 2.762836907678134e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 522,  Time [days] = 355,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30672000 t1 = 30758400 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 18 iterations, error = 7.672940039633126e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 523,  Time [days] = 356,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30758400 t1 = 30844800 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 9 iterations, error = 5.783215217399967e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 524,  Time [days] = 357,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30844800 t1 = 30931200 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 8 iterations, error = 9.74735745119727e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 525,  Time [days] = 358,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 30931200 t1 = 31017600 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 9 iterations, error = 4.968152286629736e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 526,  Time [days] = 359,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 31017600 t1 = 31104000 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 18 iterations, error = 1.271077016632704e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 527,  Time [days] = 360,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 31104000 t1 = 31190400 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 8 iterations, error = 7.516263393302333e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 528,  Time [days] = 361,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 31190400 t1 = 31276800 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 9 iterations, error = 6.127391656659964e-08
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 529,  Time [days] = 362,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 31276800 t1 = 31363200 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 7 iterations, error = 3.559014989710393e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 530,  Time [days] = 363,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 31363200 t1 = 31449600 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 12 iterations, error = 7.226504475895912e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 531,  Time [days] = 364,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 31449600 t1 = 31536000 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 9 iterations, error = 5.402715044675724e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |
# Coordinator        |   Cycle = 532,  Time [days] = 365,  dt [days] = 1
# Coordinator        |   ----------------------------------------------------------------------
# top level MPC      |   ----------------------------------------------------------------
# top level MPC      |   Advancing: t0 = 31536000 t1 = 31622400 h = 86400
# top level MPC      |   ----------------------------------------------------------------
# Solver::NKA_BT_ATS |     Solve succeeded: 8 iterations, error = 3.42962959984357e-07
# top level MPC      |   successful timestep
# Coordinator        |   ======================================================================
# Coordinator        |   All meshes combined have 404 cells.
# Coordinator        |   Memory usage (high water mark):
# Coordinator        |     Maximum per core:      84.3 MBytes,  maximum per cell: 218852.1 Bytes
# Coordinator        |     Minimum per core:      84.3 MBytes,  minimum per cell: 218852.1 Bytes
# Coordinator        |     Total:                 84.3 MBytes,  total per cell:   218852.1 Bytes
# Coordinator        |   Doubles allocated in state fields
# Coordinator        |     Maximum per core:       0.6 MBytes
# Coordinator        |     Minimum per core:       0.6 MBytes
# Coordinator        |     Total:                  0.6 MBytes
# Simulation Driver  |  ================================================================================
# Simulation Driver  |
# Simulation Driver  |                        TimeMonitor results over 1 processor
# Simulation Driver  |
# Simulation Driver  |  Timer Name                                Global time (num calls)
# Simulation Driver  |  --------------------------------------------------------------------------------
# Simulation Driver  |  Epetra_CrsMatrix::Multiply(TransA,X,Y)    0.8735 (3.604e+04)
# Simulation Driver  |  cycle                                     74.2667 (1)
# Simulation Driver  |  setup                                     0.3640 (1)
# Simulation Driver  |  volume mesh creation                      0.0635 (0)
# Simulation Driver  |  ================================================================================
# CPU times: user 159 ms, sys: 51.6 ms, total: 211 ms
# Wall time: 1min 22s
# 0

# %%
# Running tempchek
#subprocess.run(['tempchek'], capture_output=True, text=True).stdout

# %%
file_name
# Out:
# 'Case5_III_su_cv'

# %% [markdown]
# ### Run it in terminal

# %%
# Running tempchek

subprocess.run(['singularity exec /bigwork/nhgjrabl/Singularity/ats_pest_final_2.sif tempchek',f'{file_name}.xml.tpl'], capture_output=True, text=True).stdout
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 # Running tempchek
# ----> 2 subprocess.run(['singularity exec /bigwork/nhgjrabl/Singularity/ats_pest_final_2.sif tempchek',f'{file_name}.xml.tpl'], capture_output=True, text=True).stdout
#
# File /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py:493, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     490     kwargs['stdout'] = PIPE
#     491     kwargs['stderr'] = PIPE
# --> 493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
#     495         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py:858, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     854         if self.text_mode:
#     855             self.stderr = io.TextIOWrapper(self.stderr,
#     856                     encoding=encoding, errors=errors)
# --> 858     self._execute_child(args, executable, preexec_fn, close_fds,
#     859                         pass_fds, cwd, env,
#     860                         startupinfo, creationflags, shell,
#     861                         p2cread, p2cwrite,
#     862                         c2pread, c2pwrite,
#     863                         errread, errwrite,
#     864                         restore_signals, start_new_session)
#     865 except:
#     866     # Cleanup if the child failed starting.
#     867     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py:1704, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1702     if errno_num != 0:
#    1703         err_msg = os.strerror(errno_num)
# -> 1704     raise child_exception_type(errno_num, err_msg, err_filename)
#    1705 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'singularity exec /bigwork/nhgjrabl/Singularity/ats_pest_final_2.sif tempchek'

# %%
# Running inschek
subprocess.run(['singularity exec /bigwork/nhgjrabl/Singularity/ats_pest_final_2.sif inschek',f'{file_name}_obs_data.dat.ins'], capture_output=True, text=True).stdout
# Out:
# ' INSCHEK Version 17.3. Watermark Numerical Computing.\n\n Errors in file Case5_I_cv_obs_data.dat.ins ----->\n No errors encountered.\n\n 15344 observations identified in file Case5_I_cv_obs_data.dat.ins: these are \n   listed in file Case5_I_cv_obs_data.dat.obf.\n\n'

# %%
os.chdir(f'{directory_name}')

# %%
### Converting the pest control file to version 1

# %%
import pyemu
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 import pyemu
#
# ModuleNotFoundError: No module named 'pyemu'

# %%
os.getcwd()
# Out:
# /home/rk/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '/home/rk/pestpp/pestpp/rk_model_final_4yrs_su/Case5_su_cv_start_cl.demo'

# %%
directory_name
# Out:
# 'Case5_su_cv_start_cl.demo'

# %%
pst = pyemu.Pst(f"{file_name}_cf.pst")
pst.write(f"{file_name}_cf_v1.pst")
# Out:
# /home/rk/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# noptmax:-1, npar_adj:12, nnz_obs:15344

# %%
os.getcwd()
# Out:
# '/bigwork/nhgjrabl/Simulations/datamshapratirupa/5_calib/Case3_ces_calib/Case3_ces_start_cl.demo'

# %%
### Checking the pest control file once more

subprocess.run(['pestchek',f"{file_name}_cf_v1.pst"], capture_output=True, text=True).stdout
# Out:
# ' PESTCHEK Version 17.3. Watermark Numerical Computing.\n\n Errors ----->\n No errors encountered.\n\n Warnings ----->\n It appears that the PEST control file contains a "rsi" section. PESTCHEK did \n   not check this. It can only be used by RSI_HP.\n NUMLAM is supplied as negative. This will be reset to positive. If Parallel \n   PEST or BEOPEST is used PARLAM will automatically be set to -9999.\n NOPTMAX provided as -1. No optimisation will be carried out; objective \n   function, residuals and statistics will be recorded for initial parameter \n   estimates only.\n MAXSING in the singular value decomposition section is greater than the \n   number of adjustable parameters.\n'

# %% [markdown]
# * If the error of DERCOM appears - Just remove 1 from the all the par_data lines!

# %% [markdown]
# #### Change the file name in 'ats_modelcmd_cl.py' to pest file name

# %%
os.getcwd()
# Out:
# '/bigwork/nhgjrabl/Simulations/datamshapratirupa/5_calib/Case3_ces_calib/Case3_ces_start_cl.demo'

# %%
# %%time
### Running pest file

os.system(f'pest {file_name}_cf_v1.pst')
#subprocess.run(['pest',f'{file_name}_cf_v1.pst','&>out.log'], capture_output=True, text=True).stdout
# Out:
# CPU times: user 10.7 s, sys: 2.94 s, total: 13.7 s
# Wall time: 3d 17h 29min 35s
# 0

# %% [markdown]
# ### Reweighting strategy - PWTADJ1

# %%
subprocess.run(['singularity exec /bigwork/nhgjrabl/Singularity/ats_pest_final_2.sif pwtadj1'], capture_output=True, text=True).stdout
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_229422/2122354537.py in <module>
# ----> 1 subprocess.run(['singularity exec /bigwork/nhgjrabl/Singularity/ats_pest_final_2.sif pwtadj1'], capture_output=True, text=True).stdout
#
# /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     491         kwargs['stderr'] = PIPE
#     492
# --> 493     with Popen(*popenargs, **kwargs) as process:
#     494         try:
#     495             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     856                             encoding=encoding, errors=errors)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#     860                                 startupinfo, creationflags, shell,
#
# /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1702                     if errno_num != 0:
#    1703                         err_msg = os.strerror(errno_num)
# -> 1704                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1705                 raise child_exception_type(err_msg)
#    1706
#
# FileNotFoundError: [Errno 2] No such file or directory: 'singularity exec /bigwork/nhgjrabl/Singularity/ats_pest_final_2.sif pwtadj1'

# %% [markdown]
# ### Check the total objective function value in the .rec file and add in the cmd below:

# %% [markdown]
# Objective function ----->
#
#    Sum of squared weighted residuals (ie phi)                =  **1.26499E-02**
#
#    Contribution to phi from observation group "temp"         =  5.39994E-04
#
#    Contribution to phi from observation group "mois"         =  1.21099E-02

# %%
obj_fn_value = 1.26499E-02 # Taken from .rec file

# %%
obj_fn_value/2
# Out:
# 0.00632495

# %%
subprocess.run(['pwtadj1',f'{file_name}_cf_v1.pst',f'{file_name}_cf_v1_rw.pst',f'{obj_fn_value/2}'], capture_output=True, text=True).stdout
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 subprocess.run(['pwtadj1',f'{file_name}_cf_v1.pst',f'{file_name}_cf_v1_rw.pst',f'{obj_fn_value/2}'], capture_output=True, text=True).stdout
#
# File /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py:493, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     490     kwargs['stdout'] = PIPE
#     491     kwargs['stderr'] = PIPE
# --> 493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
#     495         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py:858, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     854         if self.text_mode:
#     855             self.stderr = io.TextIOWrapper(self.stderr,
#     856                     encoding=encoding, errors=errors)
# --> 858     self._execute_child(args, executable, preexec_fn, close_fds,
#     859                         pass_fds, cwd, env,
#     860                         startupinfo, creationflags, shell,
#     861                         p2cread, p2cwrite,
#     862                         c2pread, c2pwrite,
#     863                         errread, errwrite,
#     864                         restore_signals, start_new_session)
#     865 except:
#     866     # Cleanup if the child failed starting.
#     867     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /sw-eb/system/home/ood/conda/envs/miniconda3-2021.11_python-3.8/lib/python3.8/subprocess.py:1704, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1702     if errno_num != 0:
#    1703         err_msg = os.strerror(errno_num)
# -> 1704     raise child_exception_type(errno_num, err_msg, err_filename)
#    1705 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pwtadj1'

# %%
# Removing the out.log file since it's file size is large
subprocess.run(['rm','-rf','out.log'], capture_output=True, text=True).stdout
# Out:
# ''

# %%
os.chdir(f'..')

# %%
os.getcwd()
# Out:
# '/home/rk/pestpp/pestpp/rk_model_final_4yrs'

# %%
file_name
# Out:
# 'Case5_I_cv'

# %%
directory_name_rw = f'{file_name}_rw_2.demo'

# %%
directory_name_rw
# Out:
# 'Case5_I_cv_rw_2.demo'

# %%
# Copying the files to a new folder
shutil.copytree(directory_name, directory_name_rw)
# Out:
# 'Case5_I_cv_rw_2.demo'

# %%
os.chdir(f'{directory_name_rw}')

# %%
cf_name = f'{file_name}_cf_v1' # Control file name before reweighting

# %%
# Removing unnecessary files to provide space for the simulation
# Check once more if all the files have been removed properly
os.system(f'rm {cf_name}.drf {cf_name}.jac {cf_name}.jst {cf_name}.jco {cf_name}.mtt {cf_name}.par {cf_name}.rec {cf_name}.rei {cf_name}.res {cf_name}.sen {cf_name}.seo {cf_name}.svd {cf_name}.rst jacob.runs')
# Out:
# 0

# %%
file_name
# Out:
# 'Case5_I_cv'

# %%
# %%time
# Running the new re-weighted pest file
os.system(f'pestpp-glm {file_name}_cf_v1_rw.pst')
# Prefer running it on the terminal?
